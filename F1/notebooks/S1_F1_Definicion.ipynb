# %% [markdown]
# # Notebook de definición del problema y entorno reproducible — Fase 1
#
# **Proyecto transversal · MCDI500 Programación para la Ciencia de Datos**
# **Magíster en Ciencia de Datos e Inteligencia Artificial · Universidad Andrés Bello**
#
# **Grupo 5 — Factores asociados a la duración autorizada de los permisos de uso de vía
# pública en San Francisco**

# %% [markdown]
# ## Introducción
#
# Este cuaderno deja establecido lo que la Fase 2 necesita para empezar: la definición del
# problema, un entorno verificado, la estructura del repositorio con sus artefactos de
# reproducibilidad, un módulo propio importable y la documentación del conjunto de datos con su
# evaluación contra los criterios del curso.
#
# No transforma datos: los define. La limpieza, la imputación y el escalamiento son trabajo de
# la Fase 2, que lee lo que aquí se decide en lugar de volver a decidirlo.
#
# **Orden de ejecución.** Lineal, de arriba abajo. *Kernel → Restart Kernel and Run All Cells*
# debe terminar sin errores y con la numeración de ejecución continua.

# %% [markdown]
# ### Herramientas del ecosistema científico
#
# Cada importación responde a una necesidad concreta de esta fase y no se incluye ninguna que
# no se use. `pathlib` resuelve rutas de forma independiente del sistema operativo; `subprocess`
# y `shutil` consultan el estado real de Git sin suponer que esté instalado; `json` exporta los
# metadatos en un formato legible tanto por una persona como por el cuaderno de la Fase 2.

# %%
import sys                       # intérprete en uso: es lo que se verifica más abajo
import json                      # exportación de metadatos legibles
import platform                  # sistema operativo, para dejarlo en la bitácora
import subprocess                # consultas a Git desde el cuaderno
import shutil                    # localizar ejecutables (git) sin suponer que existen
import importlib                 # importar el módulo que este cuaderno va a escribir
import warnings                  # capturar los avisos de parseo como evidencia, no como ruido
import io, contextlib            # capturar salidas para los anexos del informe
from pathlib import Path         # manejo de rutas independiente del sistema operativo
from datetime import date

import numpy as np               # presente para verificar el entorno del proyecto
import pandas as pd              # tablas de documentación de la fase

# Reproducibilidad: la misma semilla que usa el cuaderno de la Fase 2.
SEMILLA = 42
np.random.seed(SEMILLA)

def capturar(funcion, *args, **kwargs):
    """
    Ejecuta una funcion, muestra su salida en pantalla y ademas la devuelve como texto.

    Sirve para que los anexos del informe se generen desde la misma ejecucion que produce
    los resultados, en lugar de copiarse a mano desde una captura de pantalla.

    Retorna
    -------
    (obj, str)
        Lo que devuelva la funcion y su salida estandar como texto.
    """
    buffer = io.StringIO()
    with contextlib.redirect_stdout(buffer):
        resultado = funcion(*args, **kwargs)
    texto = buffer.getvalue()
    print(texto, end="")
    return resultado, texto


print("Cuaderno de la Fase 1 ·", date.today().isoformat())
# Out:
# Cuaderno de la Fase 1 · 2026-09-16

# %% [markdown]
# ## 1. Definición del problema
#
# Toda la identificación del proyecto vive en un único diccionario. Lo que el cuaderno imprima
# o persista después se deriva de aquí, de modo que no circulen dos versiones del título, de la
# pregunta o de los integrantes.
#
# > **Completar antes de entregar:** los nombres de los tres integrantes. El correo
# > configurado en Git debe coincidir con el de su cuenta de GitHub, o los *commits* no se les
# > atribuyen.

# %%
PROYECTO = {
    "titulo": "Factores asociados a la duración autorizada de los permisos de uso de vía "
              "pública en San Francisco",
    "grupo": "Grupo 5",
    "asignatura": "MCDI500 · Programación para la Ciencia de Datos",
    "integrantes": [
        "MARCO ÁLVAREZ ARAYA (@Marco30101994-Unab)",
        "MARÍA FASSLER NEUMANN (@belenfassler)",
        "RICARDO JARAMILLO PULGAR (@RJaramilloP)"],
    "problematica": (
        "Los permisos de uso de vía pública regulan la ocupación temporal del espacio público "
        "por excavaciones, obras, instalaciones de telecomunicaciones y usos comerciales. La "
        "duración autorizada de cada permiso determina cuánto tiempo una calle queda afectada. "
        "El problema es de asociación: identificar qué factores se relacionan con esa duración, "
        "medida como el número de días entre la fecha de inicio y la de término del permiso."
    ),
    "objetivo_general": (
        "Identificar y cuantificar los factores asociados a la duración autorizada de los "
        "permisos de uso de vía pública vigentes en San Francisco, mediante un flujo "
        "reproducible de obtención, saneamiento y validación de datos abiertos."
    ),
    "objetivos_especificos": [
        "Definir el problema y establecer el entorno reproducible del proyecto (F1).",
        "Documentar la procedencia, la licencia y el rol analítico de cada variable (F1).",
        "Construir el pipeline de obtención, limpieza y transformación de datos (F2).",
        "Implementar el núcleo algorítmico con programación estructurada y POO (F3).",
        "Comunicar los hallazgos mediante visualización y un informe técnico (F4).",
    ],
    "preguntas": [
        "¿Qué proporción de la variación en la duración se asocia al tipo de permiso?",
        "Dentro de un mismo tipo, ¿el barrio y el agente solicitante distinguen duraciones?",
        "¿Qué variables concentran los faltantes y qué significa que un dato no esté?",
    ],
    "criterios_exito": [
        "El repositorio se clona y ambos cuadernos corren completos sin intervención manual.",
        "Cada decisión de preprocesamiento queda justificada con cifras, no con adjetivos.",
        "Los tres integrantes tienen commits propios en el historial.",
    ],
    "alcance": {
        "incluye": ["Definición del problema", "Entorno reproducible",
                    "Selección y documentación del conjunto"],
        "excluye": ["Limpieza e imputación", "Modelado", "Inferencia causal"],
    },
    "limitaciones": [
        "Los datos son secundarios: no se controló su recolección ni su representatividad.",
        "La fuente publica solo permisos vigentes, de modo que los de mayor duración quedan "
        "sobrerrepresentados. Se cuantifica en la sección 5.4.",
        "El portal se actualiza a diario: los resultados corresponden a un corte concreto y no "
        "son reproducibles descargando el archivo de nuevo.",
    ],
}

# %% [markdown]
# La función siguiente presenta el proyecto en pantalla. Recibe el diccionario como
# parámetro en lugar de leer una variable global, de modo que pueda reutilizarse y probarse con
# cualquier configuración. Falla temprano y con un mensaje que dice **qué** falta, no solo que
# algo salió mal.

# %%
def presentar_proyecto(config):
    """
    Imprime la definicion del proyecto de forma legible.

    Parametros
    ----------
    config : dict
        Diccionario de configuracion del proyecto.

    Retorna
    -------
    None

    Lanza
    -----
    KeyError
        Si falta alguna de las claves obligatorias.
    """
    obligatorias = ("titulo", "problematica", "objetivo_general", "objetivos_especificos")
    faltantes = [c for c in obligatorias if c not in config]
    if faltantes:
        # Se falla temprano y con un mensaje que dice QUE falta, no solo que algo fallo.
        raise KeyError(f"Faltan claves obligatorias en la configuracion: {faltantes}")

    print(config["titulo"].upper())
    print("=" * 60)
    print(f"{config['asignatura']} · {config['grupo']}")
    print("\nProblemática")
    print(config["problematica"])
    print("\nObjetivo general")
    print(config["objetivo_general"])
    print("\nObjetivos específicos")
    for i, obj in enumerate(config["objetivos_especificos"], start=1):
        print(f"  {i}. {obj}")
    print("\nPreguntas que orientan el trabajo")
    for pregunta in config["preguntas"]:
        print(f"  · {pregunta}")


presentar_proyecto(PROYECTO)
# Out:
# FACTORES ASOCIADOS A LA DURACIÓN AUTORIZADA DE LOS PERMISOS DE USO DE VÍA PÚBLICA EN SAN FRANCISCO
# ============================================================
# MCDI500 · Programación para la Ciencia de Datos · Grupo 5
#
# Problemática
# Los permisos de uso de vía pública regulan la ocupación temporal del espacio público por excavaciones, obras, instalaciones de telecomunicaciones y usos comerciales. La duración autorizada de cada permiso determina cuánto tiempo una calle queda afectada. El problema es de asociación: identificar qué factores se relacionan con esa duración, medida como el número de días entre la fecha de inicio y la de término del permiso.
#
# Objetivo general
# Identificar y cuantificar los factores asociados a la duración autorizada de los permisos de uso de vía pública vigentes en San Francisco, mediante un flujo reproducible de obtención, saneamiento y validación de datos abiertos.
#
# Objetivos específicos
#   1. Definir el problema y establecer el entorno reproducible del proyecto (F1).
#   2. Documentar la procedencia, la licencia y el rol analítico de cada variable (F1).
#   3. Construir el pipeline de obtención, limpieza y transformación de datos (F2).
#   4. Implementar el núcleo algorítmico con programación estructurada y POO (F3).
#   5. Comunicar los hallazgos mediante visualización y un informe técnico (F4).
#
# Preguntas que orientan el trabajo
#   · ¿Qué proporción de la variación en la duración se asocia al tipo de permiso?
#   · Dentro de un mismo tipo, ¿el barrio y el agente solicitante distinguen duraciones?
#   · ¿Qué variables concentran los faltantes y qué significa que un dato no esté?

# %% [markdown]
# El alcance y las limitaciones se presentan aparte porque cumplen una función distinta:
# el primero delimita qué entra en esta entrega y qué no; las segundas declaran qué no puede
# afirmarse con estos datos, por bien que se haga el trabajo.

# %%
print("Alcance de la Fase 1")
print("  Incluye:", ", ".join(PROYECTO["alcance"]["incluye"]))
print("  Excluye:", ", ".join(PROYECTO["alcance"]["excluye"]))

print("\nLimitaciones declaradas")
for lim in PROYECTO["limitaciones"]:
    print(f"  · {lim}")
# Out:
# Alcance de la Fase 1
#   Incluye: Definición del problema, Entorno reproducible, Selección y documentación del conjunto
#   Excluye: Limpieza e imputación, Modelado, Inferencia causal
#
# Limitaciones declaradas
#   · Los datos son secundarios: no se controló su recolección ni su representatividad.
#   · La fuente publica solo permisos vigentes, de modo que los de mayor duración quedan sobrerrepresentados. Se cuantifica en la sección 5.4.
#   · El portal se actualiza a diario: los resultados corresponden a un corte concreto y no son reproducibles descargando el archivo de nuevo.

# %% [markdown]
# > **Sobre las limitaciones.** Declararlas antes de haber analizado nada es señal de haber
# > entendido la fuente, no de desconfianza en el trabajo. La segunda de ellas —la
# > sobrerrepresentación de los permisos largos— no es una sospecha: la sección 5.4 la mide y
# > muestra que la duración mínima observada crece con la antigüedad del permiso, que es
# > exactamente lo que predice el mecanismo.

# %% [markdown]
# ## 2. Verificación del entorno
#
# Se registra el entorno **realmente en uso**, no el que se esperaba tener. Si alguna versión
# difiere entre integrantes, esta salida lo revela antes de que se convierta en un resultado
# distinto sin explicación.

# %%
DEPENDENCIAS = ["numpy", "pandas", "matplotlib", "sklearn"]

# Correspondencia entre el nombre de importación y el nombre del paquete en PyPI:
# se instala scikit-learn, pero se importa sklearn.
NOMBRE_EN_PYPI = {"sklearn": "scikit-learn"}


def verificar_entorno(dependencias):
    """
    Comprueba interprete, entorno virtual, carpeta de trabajo y librerias.

    Parametros
    ----------
    dependencias : list of str
        Nombres de importacion de las librerias que el proyecto declara.

    Retorna
    -------
    dict
        Resultado de cada comprobacion, para dejarlo en la bitacora de la fase.
    """
    reporte = {}

    # 1. Interprete que ejecuta ESTE cuaderno. Si la ruta no contiene .venv,
    #    el kernel no es el del proyecto: Kernel -> Change Kernel.
    ejecutable = Path(sys.executable)
    en_venv = ".venv" in ejecutable.parts or sys.prefix != sys.base_prefix
    reporte["interprete"] = str(ejecutable)
    reporte["entorno_virtual"] = bool(en_venv)
    print("Intérprete       :", ejecutable)
    print("Entorno virtual  :", "[OK] activo" if en_venv else "[AVISO] parece el Python del sistema")

    # 2. Carpeta de trabajo: las rutas relativas se resuelven desde aqui,
    #    no desde donde esta guardado el archivo .ipynb.
    reporte["carpeta_trabajo"] = str(Path.cwd())
    print("Carpeta de trabajo:", Path.cwd())
    print("Sistema          :", platform.system(), platform.release())
    print("Python           :", sys.version.split()[0])

    # 3. Librerias del proyecto, con su version.
    print("\nLibrerías declaradas")
    versiones = {}
    for nombre in dependencias:
        try:
            modulo = importlib.import_module(nombre)
            version = getattr(modulo, "__version__", "sin atributo __version__")
            versiones[nombre] = version
            print(f"  [OK]    {nombre:12} {version}")
        except ImportError:
            # No se interrumpe el cuaderno: se informa que instalar y con que nombre.
            versiones[nombre] = None
            paquete = NOMBRE_EN_PYPI.get(nombre, nombre)
            print(f"  [FALTA] {nombre:12} instale con: python -m pip install {paquete}")
    reporte["versiones"] = versiones
    return reporte


ENTORNO, ANEXO_A = capturar(verificar_entorno, DEPENDENCIAS)   # Anexo A del informe
# Out:
# Intérprete       : /Users/ricardo/Desktop/Repositorios/proyecto-grupo5-mcdi500/.venv/bin/python
# Entorno virtual  : [OK] activo
# Carpeta de trabajo: /Users/ricardo/Desktop/Repositorios/proyecto-grupo5-mcdi500/F1/notebooks
# Sistema          : Darwin 25.6.0
# Python           : 3.9.13
#
# Librerías declaradas
#   [OK]    numpy        2.0.2
#   [OK]    pandas       2.3.3
#   [OK]    matplotlib   3.9.4
#   [OK]    sklearn      1.6.1

# %% [markdown]
# **Cómo se lee este resultado.** Cada línea corresponde a un acoplamiento que la
# reproducibilidad exige explicitar. Si el intérprete no apunta al `.venv` del proyecto, el
# cuaderno está corriendo con las librerías del sistema y las versiones que se registren más
# abajo no serán las que el grupo declaró. Si alguna librería aparece como `[FALTA]`, el
# cuaderno no se interrumpe: informa qué instalar, porque detenerse obligaría a reejecutar todo
# desde el principio por un problema que se resuelve en una línea.

# %% [markdown]
# ## 3. Estructura del repositorio y artefactos
#
# Las rutas de datos son **comunes a todas las fases**: son exactamente las que usa el cuaderno
# de la Fase 2, de modo que un mismo archivo sirva a los dos. Cada fase tiene su propia carpeta
# para cuadernos e informes.

# %%
MARCADORES = (".git", "requirements.txt", ".gitignore")


def localizar_raiz(inicio=None, marcadores=MARCADORES, niveles=5, respaldo=True):
    """
    Resuelve la raiz del proyecto subiendo hasta encontrar un marcador.

    Parametros
    ----------
    inicio : str | Path | None
        Punto de partida. Por defecto, el directorio de trabajo actual.
    marcadores : tuple of str
        Archivos o carpetas que identifican la raiz de un repositorio.
    niveles : int
        Numero maximo de directorios padre a recorrer.
    respaldo : bool
        Si es True y no hay marcador, retorna `inicio` (disposicion plana).

    Retorna
    -------
    (Path, str)
        Ruta de la raiz y modo detectado: "estructurado" o "plano".

    Lanza
    -----
    FileNotFoundError
        Si no hay marcador y respaldo es False.
    """
    actual = Path(inicio or Path.cwd()).resolve()
    for candidata in [actual, *actual.parents][:niveles + 1]:
        if any((candidata / m).exists() for m in marcadores):
            return candidata, "estructurado"
    if respaldo:
        return actual, "plano"
    raise FileNotFoundError(f"No se encontro marcador de repositorio desde {actual}.")


RAIZ, MODO = localizar_raiz()        # raiz del proyecto, no del directorio de lanzamiento

# Rutas de datos COMUNES a todas las fases.
DIR_CRUDO = RAIZ / "data" / "raw"            # datos originales: nunca se modifican
DIR_PROCESADO = RAIZ / "data" / "processed"  # salida del pipeline de la Fase 2
DIR_DOCS = RAIZ / "docs"                     # diccionario, fichas y metadatos
DIR_SRC = RAIZ / "src"                       # modulos propios reutilizables

# Una carpeta por fase para cuadernos e informes.
DIR_FASES = [RAIZ / f"F{n}" for n in (1, 2, 3, 4)]

for carpeta in [DIR_CRUDO, DIR_PROCESADO, DIR_DOCS, DIR_SRC, *DIR_FASES]:
    # parents=True crea las intermedias; exist_ok=True evita el error si ya existen,
    # que es lo que permite volver a ejecutar el cuaderno completo sin romperlo.
    carpeta.mkdir(parents=True, exist_ok=True)

print("Raíz del proyecto :", RAIZ)
print("Modo detectado    :", MODO)
print("Ejecutado desde   :", Path.cwd())
print("\nEstructura creada:")
for ruta in sorted(p for p in RAIZ.rglob("*") if p.is_dir() and ".git" not in p.parts
                   and ".ipynb_checkpoints" not in p.parts and "__pycache__" not in p.parts):
    print("  ", ruta.relative_to(RAIZ).as_posix() + "/")
# Out:
# Raíz del proyecto : /Users/ricardo/Desktop/Repositorios/proyecto-grupo5-mcdi500
# Modo detectado    : estructurado
# Ejecutado desde   : /Users/ricardo/Desktop/Repositorios/proyecto-grupo5-mcdi500/F1/notebooks
#
# Estructura creada:
#    .venv/
#    .venv/bin/
#    .venv/etc/
#    .venv/etc/jupyter/
#    .venv/etc/jupyter/jupyter_notebook_config.d/
#    .venv/etc/jupyter/jupyter_server_config.d/
#    .venv/include/
#    .venv/lib/
#    .venv/lib/python3.9/
#    .venv/lib/python3.9/site-packages/
#    .venv/lib/python3.9/site-packages/IPython/
#    .venv/lib/python3.9/site-packages/IPython/core/
#    .venv/lib/python3.9/site-packages/IPython/core/magics/
#    .venv/lib/python3.9/site-packages/IPython/core/profile/
#    .venv/lib/python3.9/site-packages/IPython/core/tests/
#    .venv/lib/python3.9/site-packages/IPython/core/tests/daft_extension/
#    .venv/lib/python3.9/site-packages/IPython/extensions/
#    .venv/lib/python3.9/site-packages/IPython/extensions/tests/
#    .venv/lib/python3.9/site-packages/IPython/external/
#    .venv/lib/python3.9/site-packages/IPython/external/tests/
#    .venv/lib/python3.9/site-packages/IPython/lib/
#    .venv/lib/python3.9/site-packages/IPython/lib/tests/
#    .venv/lib/python3.9/site-packages/IPython/sphinxext/
#    .venv/lib/python3.9/site-packages/IPython/terminal/
#    .venv/lib/python3.9/site-packages/IPython/terminal/pt_inputhooks/
#    .venv/lib/python3.9/site-packages/IPython/terminal/shortcuts/
#    .venv/lib/python3.9/site-packages/IPython/terminal/tests/
#    .venv/lib/python3.9/site-packages/IPython/testing/
#    .venv/lib/python3.9/site-packages/IPython/testing/plugin/
#    .venv/lib/python3.9/site-packages/IPython/testing/tests/
#    .venv/lib/python3.9/site-packages/IPython/utils/
#    .venv/lib/python3.9/site-packages/IPython/utils/tests/
#    .venv/lib/python3.9/site-packages/PIL/
#    .venv/lib/python3.9/site-packages/PIL/.dylibs/
#    .venv/lib/python3.9/site-packages/_argon2_cffi_bindings/
#    .venv/lib/python3.9/site-packages/_distutils_hack/
#    .venv/lib/python3.9/site-packages/_yaml/
#    .venv/lib/python3.9/site-packages/anyio/
#    .venv/lib/python3.9/site-packages/anyio/_backends/
#    .venv/lib/python3.9/site-packages/anyio/_core/
#    .venv/lib/python3.9/site-packages/anyio/abc/
#    .venv/lib/python3.9/site-packages/anyio/streams/
#    .venv/lib/python3.9/site-packages/anyio-4.12.1.dist-info/
#    .venv/lib/python3.9/site-packages/anyio-4.12.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/appnope/
#    .venv/lib/python3.9/site-packages/appnope-1.0.0.dist-info/
#    .venv/lib/python3.9/site-packages/appnope-1.0.0.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/argon2/
#    .venv/lib/python3.9/site-packages/argon2_cffi-25.1.0.dist-info/
#    .venv/lib/python3.9/site-packages/argon2_cffi-25.1.0.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/argon2_cffi_bindings-25.1.0.dist-info/
#    .venv/lib/python3.9/site-packages/argon2_cffi_bindings-25.1.0.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/arrow/
#    .venv/lib/python3.9/site-packages/arrow-1.4.0.dist-info/
#    .venv/lib/python3.9/site-packages/arrow-1.4.0.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/asttokens/
#    .venv/lib/python3.9/site-packages/asttokens-3.0.2.dist-info/
#    .venv/lib/python3.9/site-packages/asttokens-3.0.2.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/async_lru/
#    .venv/lib/python3.9/site-packages/async_lru-2.0.5.dist-info/
#    .venv/lib/python3.9/site-packages/attr/
#    .venv/lib/python3.9/site-packages/attrs/
#    .venv/lib/python3.9/site-packages/attrs-26.1.0.dist-info/
#    .venv/lib/python3.9/site-packages/attrs-26.1.0.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/babel/
#    .venv/lib/python3.9/site-packages/babel/locale-data/
#    .venv/lib/python3.9/site-packages/babel/localtime/
#    .venv/lib/python3.9/site-packages/babel/messages/
#    .venv/lib/python3.9/site-packages/babel-2.18.0.dist-info/
#    .venv/lib/python3.9/site-packages/babel-2.18.0.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/beautifulsoup4-4.15.0.dist-info/
#    .venv/lib/python3.9/site-packages/beautifulsoup4-4.15.0.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/bleach/
#    .venv/lib/python3.9/site-packages/bleach/_vendor/
#    .venv/lib/python3.9/site-packages/bleach/_vendor/html5lib/
#    .venv/lib/python3.9/site-packages/bleach/_vendor/html5lib/_trie/
#    .venv/lib/python3.9/site-packages/bleach/_vendor/html5lib/filters/
#    .venv/lib/python3.9/site-packages/bleach/_vendor/html5lib/treeadapters/
#    .venv/lib/python3.9/site-packages/bleach/_vendor/html5lib/treebuilders/
#    .venv/lib/python3.9/site-packages/bleach/_vendor/html5lib/treewalkers/
#    .venv/lib/python3.9/site-packages/bleach/_vendor/html5lib-1.1.dist-info/
#    .venv/lib/python3.9/site-packages/bleach-6.2.0.dist-info/
#    .venv/lib/python3.9/site-packages/bs4/
#    .venv/lib/python3.9/site-packages/bs4/builder/
#    .venv/lib/python3.9/site-packages/certifi/
#    .venv/lib/python3.9/site-packages/certifi/tests/
#    .venv/lib/python3.9/site-packages/certifi-2026.7.22.dist-info/
#    .venv/lib/python3.9/site-packages/certifi-2026.7.22.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/cffi/
#    .venv/lib/python3.9/site-packages/cffi-2.0.0.dist-info/
#    .venv/lib/python3.9/site-packages/cffi-2.0.0.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/charset_normalizer/
#    .venv/lib/python3.9/site-packages/charset_normalizer/cli/
#    .venv/lib/python3.9/site-packages/charset_normalizer-3.5.1.dist-info/
#    .venv/lib/python3.9/site-packages/charset_normalizer-3.5.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/comm/
#    .venv/lib/python3.9/site-packages/comm-0.2.3.dist-info/
#    .venv/lib/python3.9/site-packages/comm-0.2.3.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/contourpy/
#    .venv/lib/python3.9/site-packages/contourpy/util/
#    .venv/lib/python3.9/site-packages/contourpy-1.3.0.dist-info/
#    .venv/lib/python3.9/site-packages/cycler/
#    .venv/lib/python3.9/site-packages/cycler-0.12.1.dist-info/
#    .venv/lib/python3.9/site-packages/dateutil/
#    .venv/lib/python3.9/site-packages/dateutil/parser/
#    .venv/lib/python3.9/site-packages/dateutil/tz/
#    .venv/lib/python3.9/site-packages/dateutil/zoneinfo/
#    .venv/lib/python3.9/site-packages/debugpy/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/fsnotify/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydev_runfiles/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/_debug_adapter/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_concurrency_analyser/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydevd_frame_eval/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydevd_frame_eval/vendored/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydevd_frame_eval/vendored/bytecode/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydevd_frame_eval/vendored/bytecode/tests/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/_pydevd_sys_monitoring/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydev_ipython/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydev_sitecustomize/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/common/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/linux_and_mac/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/winappdbg/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/winappdbg/win32/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_attach_to_process/windows/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_plugins/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_plugins/extensions/
#    .venv/lib/python3.9/site-packages/debugpy/_vendored/pydevd/pydevd_plugins/extensions/types/
#    .venv/lib/python3.9/site-packages/debugpy/adapter/
#    .venv/lib/python3.9/site-packages/debugpy/common/
#    .venv/lib/python3.9/site-packages/debugpy/launcher/
#    .venv/lib/python3.9/site-packages/debugpy/server/
#    .venv/lib/python3.9/site-packages/debugpy-1.8.21.dist-info/
#    .venv/lib/python3.9/site-packages/debugpy-1.8.21.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/decorator/
#    .venv/lib/python3.9/site-packages/decorator-5.3.1.dist-info/
#    .venv/lib/python3.9/site-packages/decorator-5.3.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/defusedxml/
#    .venv/lib/python3.9/site-packages/defusedxml-0.7.1.dist-info/
#    .venv/lib/python3.9/site-packages/exceptiongroup/
#    .venv/lib/python3.9/site-packages/exceptiongroup-1.3.1.dist-info/
#    .venv/lib/python3.9/site-packages/exceptiongroup-1.3.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/executing/
#    .venv/lib/python3.9/site-packages/executing-2.2.1.dist-info/
#    .venv/lib/python3.9/site-packages/fastjsonschema/
#    .venv/lib/python3.9/site-packages/fastjsonschema-2.21.2.dist-info/
#    .venv/lib/python3.9/site-packages/fastjsonschema-2.21.2.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/fontTools/
#    .venv/lib/python3.9/site-packages/fontTools/cffLib/
#    .venv/lib/python3.9/site-packages/fontTools/colorLib/
#    .venv/lib/python3.9/site-packages/fontTools/config/
#    .venv/lib/python3.9/site-packages/fontTools/cu2qu/
#    .venv/lib/python3.9/site-packages/fontTools/designspaceLib/
#    .venv/lib/python3.9/site-packages/fontTools/encodings/
#    .venv/lib/python3.9/site-packages/fontTools/feaLib/
#    .venv/lib/python3.9/site-packages/fontTools/merge/
#    .venv/lib/python3.9/site-packages/fontTools/misc/
#    .venv/lib/python3.9/site-packages/fontTools/misc/filesystem/
#    .venv/lib/python3.9/site-packages/fontTools/misc/plistlib/
#    .venv/lib/python3.9/site-packages/fontTools/mtiLib/
#    .venv/lib/python3.9/site-packages/fontTools/otlLib/
#    .venv/lib/python3.9/site-packages/fontTools/otlLib/optimize/
#    .venv/lib/python3.9/site-packages/fontTools/pens/
#    .venv/lib/python3.9/site-packages/fontTools/qu2cu/
#    .venv/lib/python3.9/site-packages/fontTools/subset/
#    .venv/lib/python3.9/site-packages/fontTools/svgLib/
#    .venv/lib/python3.9/site-packages/fontTools/svgLib/path/
#    .venv/lib/python3.9/site-packages/fontTools/t1Lib/
#    .venv/lib/python3.9/site-packages/fontTools/ttLib/
#    .venv/lib/python3.9/site-packages/fontTools/ttLib/tables/
#    .venv/lib/python3.9/site-packages/fontTools/ufoLib/
#    .venv/lib/python3.9/site-packages/fontTools/unicodedata/
#    .venv/lib/python3.9/site-packages/fontTools/varLib/
#    .venv/lib/python3.9/site-packages/fontTools/varLib/avar/
#    .venv/lib/python3.9/site-packages/fontTools/varLib/instancer/
#    .venv/lib/python3.9/site-packages/fontTools/voltLib/
#    .venv/lib/python3.9/site-packages/fonttools-4.60.2.dist-info/
#    .venv/lib/python3.9/site-packages/fonttools-4.60.2.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/fqdn/
#    .venv/lib/python3.9/site-packages/fqdn-1.5.1.dist-info/
#    .venv/lib/python3.9/site-packages/h11/
#    .venv/lib/python3.9/site-packages/h11-0.16.0.dist-info/
#    .venv/lib/python3.9/site-packages/h11-0.16.0.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/httpcore/
#    .venv/lib/python3.9/site-packages/httpcore/_async/
#    .venv/lib/python3.9/site-packages/httpcore/_backends/
#    .venv/lib/python3.9/site-packages/httpcore/_sync/
#    .venv/lib/python3.9/site-packages/httpcore-1.0.9.dist-info/
#    .venv/lib/python3.9/site-packages/httpcore-1.0.9.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/httpx/
#    .venv/lib/python3.9/site-packages/httpx/_transports/
#    .venv/lib/python3.9/site-packages/httpx-0.28.1.dist-info/
#    .venv/lib/python3.9/site-packages/httpx-0.28.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/idna/
#    .venv/lib/python3.9/site-packages/idna-3.19.dist-info/
#    .venv/lib/python3.9/site-packages/idna-3.19.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/importlib_metadata/
#    .venv/lib/python3.9/site-packages/importlib_metadata/compat/
#    .venv/lib/python3.9/site-packages/importlib_metadata-8.7.1.dist-info/
#    .venv/lib/python3.9/site-packages/importlib_metadata-8.7.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/importlib_resources/
#    .venv/lib/python3.9/site-packages/importlib_resources/compat/
#    .venv/lib/python3.9/site-packages/importlib_resources/future/
#    .venv/lib/python3.9/site-packages/importlib_resources/tests/
#    .venv/lib/python3.9/site-packages/importlib_resources/tests/compat/
#    .venv/lib/python3.9/site-packages/importlib_resources-6.5.2.dist-info/
#    .venv/lib/python3.9/site-packages/ipykernel/
#    .venv/lib/python3.9/site-packages/ipykernel/comm/
#    .venv/lib/python3.9/site-packages/ipykernel/gui/
#    .venv/lib/python3.9/site-packages/ipykernel/inprocess/
#    .venv/lib/python3.9/site-packages/ipykernel/pylab/
#    .venv/lib/python3.9/site-packages/ipykernel/resources/
#    .venv/lib/python3.9/site-packages/ipykernel-6.31.0.dist-info/
#    .venv/lib/python3.9/site-packages/ipykernel-6.31.0.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/ipython-8.18.1.dist-info/
#    .venv/lib/python3.9/site-packages/isoduration/
#    .venv/lib/python3.9/site-packages/isoduration/formatter/
#    .venv/lib/python3.9/site-packages/isoduration/operations/
#    .venv/lib/python3.9/site-packages/isoduration/parser/
#    .venv/lib/python3.9/site-packages/isoduration-20.11.0.dist-info/
#    .venv/lib/python3.9/site-packages/jedi/
#    .venv/lib/python3.9/site-packages/jedi/api/
#    .venv/lib/python3.9/site-packages/jedi/api/refactoring/
#    .venv/lib/python3.9/site-packages/jedi/inference/
#    .venv/lib/python3.9/site-packages/jedi/inference/compiled/
#    .venv/lib/python3.9/site-packages/jedi/inference/compiled/subprocess/
#    .venv/lib/python3.9/site-packages/jedi/inference/gradual/
#    .venv/lib/python3.9/site-packages/jedi/inference/value/
#    .venv/lib/python3.9/site-packages/jedi/plugins/
#    .venv/lib/python3.9/site-packages/jedi/third_party/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/apps/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/conf/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/conf/locale/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/conf/urls/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/templatetags/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admin/views/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/admindocs/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/handlers/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/management/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/auth/management/commands/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/contenttypes/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/contenttypes/management/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/contenttypes/management/commands/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/flatpages/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/flatpages/templatetags/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/gis/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/gis/db/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/gis/db/models/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/humanize/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/humanize/templatetags/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/messages/storage/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/aggregates/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/postgres/fields/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/redirects/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sessions/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sessions/backends/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sessions/management/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sessions/management/commands/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sitemaps/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sitemaps/management/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sitemaps/management/commands/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/sites/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/management/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/management/commands/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/staticfiles/templatetags/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/contrib/syndication/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/core/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/core/cache/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/core/cache/backends/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/core/checks/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/core/checks/security/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/core/files/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/core/handlers/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/core/mail/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/core/mail/backends/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/core/management/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/core/management/commands/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/core/serializers/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/core/servers/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/db/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/db/backends/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/db/backends/base/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/db/backends/dummy/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/db/backends/mysql/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/db/backends/postgresql/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/db/backends/sqlite3/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/db/migrations/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/db/migrations/operations/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/db/models/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/db/models/fields/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/db/models/functions/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/db/models/sql/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/dispatch/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/forms/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/http/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/middleware/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/template/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/template/backends/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/template/loaders/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/templatetags/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/test/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/urls/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/utils/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/utils/translation/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/views/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/views/decorators/
#    .venv/lib/python3.9/site-packages/jedi/third_party/django-stubs/django-stubs/views/generic/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2/distutils/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2/distutils/command/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2/email/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2/email/mime/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2/encodings/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2/multiprocessing/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2/multiprocessing/dummy/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2/os/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/_typeshed/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/ctypes/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/curses/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/ensurepip/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/lib2to3/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/lib2to3/pgen2/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/logging/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/msilib/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/pydoc_data/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/pyexpat/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/sqlite3/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/wsgiref/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/xml/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/xml/dom/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/xml/etree/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/xml/parsers/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/xml/parsers/expat/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/2and3/xml/sax/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/asyncio/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/collections/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/concurrent/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/concurrent/futures/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/dbm/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/distutils/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/distutils/command/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/email/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/email/mime/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/encodings/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/html/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/http/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/importlib/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/json/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/multiprocessing/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/multiprocessing/dummy/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/os/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/tkinter/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/unittest/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/urllib/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/venv/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3/xmlrpc/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3.7/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3.9/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/stdlib/3.9/zoneinfo/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2/OpenSSL/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2/concurrent/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2/concurrent/futures/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2/fb303/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2/kazoo/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2/kazoo/recipe/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2/routes/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2/scribe/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2/six/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2/six/moves/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2/six/moves/urllib/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2/tornado/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/atomicwrites/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/attr/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/backports/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/bleach/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/boto/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/boto/ec2/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/boto/elb/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/boto/kms/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/boto/s3/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/cachetools/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/characteristic/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/chardet/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/click/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/cryptography/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/cryptography/hazmat/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/cryptography/hazmat/backends/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/cryptography/hazmat/bindings/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/cryptography/hazmat/bindings/openssl/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/cryptography/hazmat/primitives/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/cryptography/hazmat/primitives/asymmetric/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/cryptography/hazmat/primitives/ciphers/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/cryptography/hazmat/primitives/kdf/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/cryptography/hazmat/primitives/serialization/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/cryptography/hazmat/primitives/twofactor/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/cryptography/x509/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/datetimerange/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/dateutil/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/dateutil/tz/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/deprecated/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/emoji/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/flask/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/flask/json/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/geoip2/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/google/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/google/protobuf/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/google/protobuf/compiler/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/google/protobuf/internal/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/google/protobuf/util/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/jinja2/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/markdown/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/markdown/extensions/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/markupsafe/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/maxminddb/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/nmap/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/paramiko/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/pyVmomi/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/pyVmomi/vim/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/pyVmomi/vmodl/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/pymysql/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/pymysql/constants/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/pynamodb/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/pynamodb/connection/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/pytz/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/redis/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/requests/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/requests/packages/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/requests/packages/urllib3/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/requests/packages/urllib3/contrib/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/requests/packages/urllib3/packages/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/requests/packages/urllib3/packages/ssl_match_hostname/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/requests/packages/urllib3/util/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/retry/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/simplejson/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/slugify/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/tzlocal/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/werkzeug/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/werkzeug/contrib/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/werkzeug/debug/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/werkzeug/middleware/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/2and3/yaml/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/aiofiles/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/aiofiles/threadpool/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/docutils/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/docutils/parsers/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/docutils/parsers/rst/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/filelock/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/freezegun/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/jwt/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/jwt/contrib/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/jwt/contrib/algorithms/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/pkg_resources/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/pyrfc3339/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/six/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/six/moves/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/six/moves/urllib/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/typed_ast/
#    .venv/lib/python3.9/site-packages/jedi/third_party/typeshed/third_party/3/waitress/
#    .venv/lib/python3.9/site-packages/jedi-0.19.2.dist-info/
#    .venv/lib/python3.9/site-packages/jinja2/
#    .venv/lib/python3.9/site-packages/jinja2-3.1.6.dist-info/
#    .venv/lib/python3.9/site-packages/jinja2-3.1.6.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/joblib/
#    .venv/lib/python3.9/site-packages/joblib/externals/
#    .venv/lib/python3.9/site-packages/joblib/externals/cloudpickle/
#    .venv/lib/python3.9/site-packages/joblib/externals/loky/
#    .venv/lib/python3.9/site-packages/joblib/externals/loky/backend/
#    .venv/lib/python3.9/site-packages/joblib/test/
#    .venv/lib/python3.9/site-packages/joblib/test/data/
#    .venv/lib/python3.9/site-packages/joblib-1.5.3.dist-info/
#    .venv/lib/python3.9/site-packages/joblib-1.5.3.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/json5/
#    .venv/lib/python3.9/site-packages/json5-0.15.0.dist-info/
#    .venv/lib/python3.9/site-packages/json5-0.15.0.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/jsonpointer-3.0.0.dist-info/
#    .venv/lib/python3.9/site-packages/jsonschema/
#    .venv/lib/python3.9/site-packages/jsonschema/benchmarks/
#    .venv/lib/python3.9/site-packages/jsonschema/benchmarks/issue232/
#    .venv/lib/python3.9/site-packages/jsonschema/tests/
#    .venv/lib/python3.9/site-packages/jsonschema/tests/typing/
#    .venv/lib/python3.9/site-packages/jsonschema-4.25.1.dist-info/
#    .venv/lib/python3.9/site-packages/jsonschema-4.25.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/jsonschema_specifications/
#    .venv/lib/python3.9/site-packages/jsonschema_specifications/schemas/
#    .venv/lib/python3.9/site-packages/jsonschema_specifications/schemas/draft201909/
#    .venv/lib/python3.9/site-packages/jsonschema_specifications/schemas/draft201909/vocabularies/
#    .venv/lib/python3.9/site-packages/jsonschema_specifications/schemas/draft202012/
#    .venv/lib/python3.9/site-packages/jsonschema_specifications/schemas/draft202012/vocabularies/
#    .venv/lib/python3.9/site-packages/jsonschema_specifications/schemas/draft3/
#    .venv/lib/python3.9/site-packages/jsonschema_specifications/schemas/draft4/
#    .venv/lib/python3.9/site-packages/jsonschema_specifications/schemas/draft6/
#    .venv/lib/python3.9/site-packages/jsonschema_specifications/schemas/draft7/
#    .venv/lib/python3.9/site-packages/jsonschema_specifications/tests/
#    .venv/lib/python3.9/site-packages/jsonschema_specifications-2025.9.1.dist-info/
#    .venv/lib/python3.9/site-packages/jsonschema_specifications-2025.9.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/jupyter_client/
#    .venv/lib/python3.9/site-packages/jupyter_client/asynchronous/
#    .venv/lib/python3.9/site-packages/jupyter_client/blocking/
#    .venv/lib/python3.9/site-packages/jupyter_client/ioloop/
#    .venv/lib/python3.9/site-packages/jupyter_client/provisioning/
#    .venv/lib/python3.9/site-packages/jupyter_client/ssh/
#    .venv/lib/python3.9/site-packages/jupyter_client-8.6.3.dist-info/
#    .venv/lib/python3.9/site-packages/jupyter_client-8.6.3.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/jupyter_core/
#    .venv/lib/python3.9/site-packages/jupyter_core/utils/
#    .venv/lib/python3.9/site-packages/jupyter_core-5.8.1.dist-info/
#    .venv/lib/python3.9/site-packages/jupyter_core-5.8.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/jupyter_events/
#    .venv/lib/python3.9/site-packages/jupyter_events/schemas/
#    .venv/lib/python3.9/site-packages/jupyter_events-0.12.1.dist-info/
#    .venv/lib/python3.9/site-packages/jupyter_events-0.12.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/jupyter_lsp/
#    .venv/lib/python3.9/site-packages/jupyter_lsp/etc/
#    .venv/lib/python3.9/site-packages/jupyter_lsp/schema/
#    .venv/lib/python3.9/site-packages/jupyter_lsp/specs/
#    .venv/lib/python3.9/site-packages/jupyter_lsp/specs/config/
#    .venv/lib/python3.9/site-packages/jupyter_lsp/tests/
#    .venv/lib/python3.9/site-packages/jupyter_lsp-2.3.1.dist-info/
#    .venv/lib/python3.9/site-packages/jupyter_lsp-2.3.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/jupyter_server/
#    .venv/lib/python3.9/site-packages/jupyter_server/auth/
#    .venv/lib/python3.9/site-packages/jupyter_server/base/
#    .venv/lib/python3.9/site-packages/jupyter_server/event_schemas/
#    .venv/lib/python3.9/site-packages/jupyter_server/event_schemas/contents_service/
#    .venv/lib/python3.9/site-packages/jupyter_server/event_schemas/gateway_client/
#    .venv/lib/python3.9/site-packages/jupyter_server/event_schemas/kernel_actions/
#    .venv/lib/python3.9/site-packages/jupyter_server/extension/
#    .venv/lib/python3.9/site-packages/jupyter_server/files/
#    .venv/lib/python3.9/site-packages/jupyter_server/gateway/
#    .venv/lib/python3.9/site-packages/jupyter_server/i18n/
#    .venv/lib/python3.9/site-packages/jupyter_server/i18n/zh_CN/
#    .venv/lib/python3.9/site-packages/jupyter_server/i18n/zh_CN/LC_MESSAGES/
#    .venv/lib/python3.9/site-packages/jupyter_server/kernelspecs/
#    .venv/lib/python3.9/site-packages/jupyter_server/nbconvert/
#    .venv/lib/python3.9/site-packages/jupyter_server/prometheus/
#    .venv/lib/python3.9/site-packages/jupyter_server/services/
#    .venv/lib/python3.9/site-packages/jupyter_server/services/api/
#    .venv/lib/python3.9/site-packages/jupyter_server/services/config/
#    .venv/lib/python3.9/site-packages/jupyter_server/services/contents/
#    .venv/lib/python3.9/site-packages/jupyter_server/services/events/
#    .venv/lib/python3.9/site-packages/jupyter_server/services/kernels/
#    .venv/lib/python3.9/site-packages/jupyter_server/services/kernels/connection/
#    .venv/lib/python3.9/site-packages/jupyter_server/services/kernelspecs/
#    .venv/lib/python3.9/site-packages/jupyter_server/services/nbconvert/
#    .venv/lib/python3.9/site-packages/jupyter_server/services/security/
#    .venv/lib/python3.9/site-packages/jupyter_server/services/sessions/
#    .venv/lib/python3.9/site-packages/jupyter_server/static/
#    .venv/lib/python3.9/site-packages/jupyter_server/static/favicons/
#    .venv/lib/python3.9/site-packages/jupyter_server/static/logo/
#    .venv/lib/python3.9/site-packages/jupyter_server/static/style/
#    .venv/lib/python3.9/site-packages/jupyter_server/templates/
#    .venv/lib/python3.9/site-packages/jupyter_server/terminal/
#    .venv/lib/python3.9/site-packages/jupyter_server/view/
#    .venv/lib/python3.9/site-packages/jupyter_server-2.18.2.dist-info/
#    .venv/lib/python3.9/site-packages/jupyter_server-2.18.2.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/jupyter_server_terminals/
#    .venv/lib/python3.9/site-packages/jupyter_server_terminals-0.5.4.dist-info/
#    .venv/lib/python3.9/site-packages/jupyter_server_terminals-0.5.4.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/jupyterlab/
#    .venv/lib/python3.9/site-packages/jupyterlab/extensions/
#    .venv/lib/python3.9/site-packages/jupyterlab/galata/
#    .venv/lib/python3.9/site-packages/jupyterlab/galata/@jupyterlab/
#    .venv/lib/python3.9/site-packages/jupyterlab/galata/@jupyterlab/galata-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/galata/@jupyterlab/galata-extension/static/
#    .venv/lib/python3.9/site-packages/jupyterlab/handlers/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/application-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/apputils-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/cell-toolbar-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/celltags-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/codemirror-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/completer-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/console-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/csvviewer-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/debugger-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/docmanager-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/documentsearch-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/extensionmanager-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/filebrowser-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/fileeditor-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/help-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/htmlviewer-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/hub-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/imageviewer-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/inspector-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/launcher-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/logconsole-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/lsp-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/mainmenu-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/markdownviewer-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/mathjax-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/metadataform-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/notebook-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/running-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/settingeditor-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/shortcuts-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/statusbar-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/terminal-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/toc-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/tooltip-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/translation-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/schemas/@jupyterlab/workspaces-extension/
#    .venv/lib/python3.9/site-packages/jupyterlab/staging/
#    .venv/lib/python3.9/site-packages/jupyterlab/staging/templates/
#    .venv/lib/python3.9/site-packages/jupyterlab/static/
#    .venv/lib/python3.9/site-packages/jupyterlab/tests/
#    .venv/lib/python3.9/site-packages/jupyterlab/tests/mock_packages/
#    .venv/lib/python3.9/site-packages/jupyterlab/tests/mock_packages/extension/
# ...
#    .venv/lib/python3.9/site-packages/soupsieve-2.8.4.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/stack_data/
#    .venv/lib/python3.9/site-packages/stack_data-0.6.3.dist-info/
#    .venv/lib/python3.9/site-packages/terminado/
#    .venv/lib/python3.9/site-packages/terminado/_static/
#    .venv/lib/python3.9/site-packages/terminado-0.18.1.dist-info/
#    .venv/lib/python3.9/site-packages/terminado-0.18.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/threadpoolctl-3.7.0.dist-info/
#    .venv/lib/python3.9/site-packages/threadpoolctl-3.7.0.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/tinycss2/
#    .venv/lib/python3.9/site-packages/tinycss2-1.4.0.dist-info/
#    .venv/lib/python3.9/site-packages/tomli/
#    .venv/lib/python3.9/site-packages/tomli-2.4.1.dist-info/
#    .venv/lib/python3.9/site-packages/tomli-2.4.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/tornado/
#    .venv/lib/python3.9/site-packages/tornado/platform/
#    .venv/lib/python3.9/site-packages/tornado/test/
#    .venv/lib/python3.9/site-packages/tornado/test/csv_translations/
#    .venv/lib/python3.9/site-packages/tornado/test/gettext_translations/
#    .venv/lib/python3.9/site-packages/tornado/test/gettext_translations/fr_FR/
#    .venv/lib/python3.9/site-packages/tornado/test/gettext_translations/fr_FR/LC_MESSAGES/
#    .venv/lib/python3.9/site-packages/tornado/test/static/
#    .venv/lib/python3.9/site-packages/tornado/test/static/dir/
#    .venv/lib/python3.9/site-packages/tornado/test/templates/
#    .venv/lib/python3.9/site-packages/tornado-6.5.10.dist-info/
#    .venv/lib/python3.9/site-packages/tornado-6.5.10.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/traitlets/
#    .venv/lib/python3.9/site-packages/traitlets/config/
#    .venv/lib/python3.9/site-packages/traitlets/tests/
#    .venv/lib/python3.9/site-packages/traitlets/utils/
#    .venv/lib/python3.9/site-packages/traitlets-5.15.1.dist-info/
#    .venv/lib/python3.9/site-packages/traitlets-5.15.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/typing_extensions-4.16.0.dist-info/
#    .venv/lib/python3.9/site-packages/typing_extensions-4.16.0.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/tzdata/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/Africa/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/America/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/America/Argentina/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/America/Indiana/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/America/Kentucky/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/America/North_Dakota/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/Antarctica/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/Arctic/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/Asia/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/Atlantic/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/Australia/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/Brazil/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/Canada/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/Chile/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/Etc/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/Europe/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/Indian/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/Mexico/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/Pacific/
#    .venv/lib/python3.9/site-packages/tzdata/zoneinfo/US/
#    .venv/lib/python3.9/site-packages/tzdata-2026.4.dist-info/
#    .venv/lib/python3.9/site-packages/tzdata-2026.4.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/tzdata-2026.4.dist-info/licenses/licenses/
#    .venv/lib/python3.9/site-packages/uri_template/
#    .venv/lib/python3.9/site-packages/uri_template-1.3.0.dist-info/
#    .venv/lib/python3.9/site-packages/urllib3/
#    .venv/lib/python3.9/site-packages/urllib3/contrib/
#    .venv/lib/python3.9/site-packages/urllib3/contrib/emscripten/
#    .venv/lib/python3.9/site-packages/urllib3/http2/
#    .venv/lib/python3.9/site-packages/urllib3/util/
#    .venv/lib/python3.9/site-packages/urllib3-2.6.3.dist-info/
#    .venv/lib/python3.9/site-packages/urllib3-2.6.3.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/wcwidth/
#    .venv/lib/python3.9/site-packages/wcwidth/table_grapheme_overrides/
#    .venv/lib/python3.9/site-packages/wcwidth-0.8.3.dist-info/
#    .venv/lib/python3.9/site-packages/wcwidth-0.8.3.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/webcolors/
#    .venv/lib/python3.9/site-packages/webcolors-24.11.1.dist-info/
#    .venv/lib/python3.9/site-packages/webcolors-24.11.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/webencodings/
#    .venv/lib/python3.9/site-packages/webencodings-0.5.1.dist-info/
#    .venv/lib/python3.9/site-packages/websocket/
#    .venv/lib/python3.9/site-packages/websocket/tests/
#    .venv/lib/python3.9/site-packages/websocket/tests/data/
#    .venv/lib/python3.9/site-packages/websocket_client-1.9.0.dist-info/
#    .venv/lib/python3.9/site-packages/websocket_client-1.9.0.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/yaml/
#    .venv/lib/python3.9/site-packages/zipp/
#    .venv/lib/python3.9/site-packages/zipp/compat/
#    .venv/lib/python3.9/site-packages/zipp-3.23.1.dist-info/
#    .venv/lib/python3.9/site-packages/zipp-3.23.1.dist-info/licenses/
#    .venv/lib/python3.9/site-packages/zmq/
#    .venv/lib/python3.9/site-packages/zmq/.dylibs/
#    .venv/lib/python3.9/site-packages/zmq/auth/
#    .venv/lib/python3.9/site-packages/zmq/backend/
#    .venv/lib/python3.9/site-packages/zmq/backend/cffi/
#    .venv/lib/python3.9/site-packages/zmq/backend/cython/
#    .venv/lib/python3.9/site-packages/zmq/devices/
#    .venv/lib/python3.9/site-packages/zmq/eventloop/
#    .venv/lib/python3.9/site-packages/zmq/green/
#    .venv/lib/python3.9/site-packages/zmq/green/eventloop/
#    .venv/lib/python3.9/site-packages/zmq/log/
#    .venv/lib/python3.9/site-packages/zmq/ssh/
#    .venv/lib/python3.9/site-packages/zmq/sugar/
#    .venv/lib/python3.9/site-packages/zmq/tests/
#    .venv/lib/python3.9/site-packages/zmq/utils/
#    .venv/share/
#    .venv/share/applications/
#    .venv/share/icons/
#    .venv/share/icons/hicolor/
#    .venv/share/icons/hicolor/scalable/
#    .venv/share/icons/hicolor/scalable/apps/
#    .venv/share/jupyter/
#    .venv/share/jupyter/kernels/
#    .venv/share/jupyter/kernels/python3/
#    .venv/share/jupyter/lab/
#    .venv/share/jupyter/lab/schemas/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/application-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/apputils-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/cell-toolbar-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/celltags-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/codemirror-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/completer-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/console-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/csvviewer-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/debugger-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/docmanager-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/documentsearch-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/extensionmanager-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/filebrowser-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/fileeditor-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/help-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/htmlviewer-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/hub-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/imageviewer-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/inspector-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/launcher-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/logconsole-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/lsp-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/mainmenu-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/markdownviewer-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/mathjax-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/metadataform-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/notebook-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/running-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/settingeditor-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/shortcuts-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/statusbar-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/terminal-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/toc-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/tooltip-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/translation-extension/
#    .venv/share/jupyter/lab/schemas/@jupyterlab/workspaces-extension/
#    .venv/share/jupyter/lab/static/
#    .venv/share/jupyter/lab/themes/
#    .venv/share/jupyter/lab/themes/@jupyterlab/
#    .venv/share/jupyter/lab/themes/@jupyterlab/theme-dark-extension/
#    .venv/share/jupyter/lab/themes/@jupyterlab/theme-dark-high-contrast-extension/
#    .venv/share/jupyter/lab/themes/@jupyterlab/theme-light-extension/
#    .venv/share/jupyter/labextensions/
#    .venv/share/jupyter/labextensions/jupyterlab_pygments/
#    .venv/share/jupyter/labextensions/jupyterlab_pygments/static/
#    .venv/share/jupyter/nbconvert/
#    .venv/share/jupyter/nbconvert/templates/
#    .venv/share/jupyter/nbconvert/templates/asciidoc/
#    .venv/share/jupyter/nbconvert/templates/base/
#    .venv/share/jupyter/nbconvert/templates/basic/
#    .venv/share/jupyter/nbconvert/templates/classic/
#    .venv/share/jupyter/nbconvert/templates/classic/static/
#    .venv/share/jupyter/nbconvert/templates/compatibility/
#    .venv/share/jupyter/nbconvert/templates/lab/
#    .venv/share/jupyter/nbconvert/templates/lab/static/
#    .venv/share/jupyter/nbconvert/templates/latex/
#    .venv/share/jupyter/nbconvert/templates/markdown/
#    .venv/share/jupyter/nbconvert/templates/python/
#    .venv/share/jupyter/nbconvert/templates/reveal/
#    .venv/share/jupyter/nbconvert/templates/reveal/static/
#    .venv/share/jupyter/nbconvert/templates/rst/
#    .venv/share/jupyter/nbconvert/templates/script/
#    .venv/share/jupyter/nbconvert/templates/webpdf/
#    .venv/share/man/
#    .venv/share/man/man1/
#    F1/
#    F1/.venv/
#    F1/.venv/bin/
#    F1/.venv/include/
#    F1/.venv/lib/
#    F1/.venv/lib/python3.9/
#    F1/.venv/lib/python3.9/site-packages/
#    F1/.venv/lib/python3.9/site-packages/_distutils_hack/
#    F1/.venv/lib/python3.9/site-packages/pip/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/cli/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/commands/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/distributions/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/index/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/locations/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/metadata/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/models/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/network/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/operations/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/operations/build/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/operations/install/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/req/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/resolution/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/resolution/legacy/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/resolution/resolvelib/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/utils/
#    F1/.venv/lib/python3.9/site-packages/pip/_internal/vcs/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/cachecontrol/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/cachecontrol/caches/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/certifi/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/chardet/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/chardet/cli/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/chardet/metadata/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/colorama/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/distlib/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/distlib/_backport/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/html5lib/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/html5lib/_trie/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/html5lib/filters/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/html5lib/treeadapters/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/html5lib/treebuilders/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/html5lib/treewalkers/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/idna/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/msgpack/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/packaging/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/pep517/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/pep517/in_process/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/pkg_resources/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/platformdirs/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/progress/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/pygments/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/pygments/filters/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/pygments/formatters/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/pygments/lexers/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/pygments/styles/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/pyparsing/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/pyparsing/diagram/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/requests/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/resolvelib/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/resolvelib/compat/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/rich/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/tenacity/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/tomli/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/contrib/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/contrib/_securetransport/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/packages/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/packages/backports/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/urllib3/util/
#    F1/.venv/lib/python3.9/site-packages/pip/_vendor/webencodings/
#    F1/.venv/lib/python3.9/site-packages/pip-22.0.4.dist-info/
#    F1/.venv/lib/python3.9/site-packages/pkg_resources/
#    F1/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/
#    F1/.venv/lib/python3.9/site-packages/pkg_resources/_vendor/packaging/
#    F1/.venv/lib/python3.9/site-packages/pkg_resources/extern/
#    F1/.venv/lib/python3.9/site-packages/pkg_resources/tests/
#    F1/.venv/lib/python3.9/site-packages/pkg_resources/tests/data/
#    F1/.venv/lib/python3.9/site-packages/pkg_resources/tests/data/my-test-package-source/
#    F1/.venv/lib/python3.9/site-packages/setuptools/
#    F1/.venv/lib/python3.9/site-packages/setuptools/_distutils/
#    F1/.venv/lib/python3.9/site-packages/setuptools/_distutils/command/
#    F1/.venv/lib/python3.9/site-packages/setuptools/_vendor/
#    F1/.venv/lib/python3.9/site-packages/setuptools/_vendor/more_itertools/
#    F1/.venv/lib/python3.9/site-packages/setuptools/_vendor/packaging/
#    F1/.venv/lib/python3.9/site-packages/setuptools/command/
#    F1/.venv/lib/python3.9/site-packages/setuptools/extern/
#    F1/.venv/lib/python3.9/site-packages/setuptools-58.1.0.dist-info/
#    F1/notebooks/
#    F2/
#    F3/
#    F4/
#    data/
#    data/processed/
#    data/raw/
#    docs/
#    docs/anexos/
#    docs/mapa_conceptual/
#    src/

# %% [markdown]
# > **Decisión que el grupo tomó y documenta.** La guía propone fijar la raíz como
# > `Path(".")`, es decir, la carpeta desde la que se lanza el cuaderno. Como este cuaderno vive
# > en `F1/notebooks/`, esa expresión crearía `data/`, `docs/` y `src/` **dentro** de
# > `F1/notebooks/`, y el cuaderno de la Fase 2 —que se lanza desde `F2/`— apuntaría a un árbol
# > distinto. El resultado sería el mismo proyecto con dos estructuras paralelas y datos
# > duplicados.
# >
# > Se sustituye por `localizar_raiz()`, que sube hasta encontrar un marcador de repositorio. El
# > cuaderno queda invariante ante el directorio de lanzamiento, que es la condición para que un
# > tercero pueda reproducirlo.
# >
# > *Enfoques descartados:* una ruta absoluta, que funciona en un solo computador; y `os.chdir()`,
# > que deja el intérprete en un estado distinto según cuántas veces se ejecute la celda.

# %% [markdown]
# ### 3.1 El archivo `.gitignore`
#
# Define qué queda fuera del control de versiones. Se escribe desde el cuaderno y se relee para
# comprobar que quedó como se esperaba: escribir un archivo y darlo por hecho es la clase de
# suposición que después cuesta horas encontrar.

# %%
CONTENIDO_GITIGNORE = """# Entorno virtual: se reconstruye con requirements.txt
.venv/
venv/

# Caché de Python
__pycache__/
*.pyc

# Jupyter
.ipynb_checkpoints/

# Windows
Thumbs.db
desktop.ini

# macOS
.DS_Store

# Variables de entorno y secretos
.env

# Datos pesados y modelos
*.ckpt
*.pth
"""

ARCHIVO_GITIGNORE = RAIZ / ".gitignore"
ARCHIVO_GITIGNORE.write_text(CONTENIDO_GITIGNORE, encoding="utf-8")

# Verificacion de ida y vuelta: se relee lo escrito antes de darlo por hecho.
lineas = [l for l in ARCHIVO_GITIGNORE.read_text(encoding="utf-8").splitlines()
          if l and not l.startswith("#")]
assert ".venv/" in lineas, "El entorno virtual debe estar ignorado."
assert ".ipynb_checkpoints/" in lineas, "Los checkpoints de Jupyter no deben versionarse."
print(f"{ARCHIVO_GITIGNORE.relative_to(RAIZ).as_posix()} escrito con {len(lineas)} reglas activas.")
# Out:
# .gitignore escrito con 11 reglas activas.

# %% [markdown]
# > **Atención — los datos.** Este `.gitignore` **no** ignora `data/`, y es una decisión
# > deliberada. La fuente de este proyecto se actualiza a diario: volver a descargar el archivo
# > produce un conjunto distinto. El archivo versionado en `data/raw/` **es** el dato, no una
# > copia de conveniencia, y sin él los resultados no se pueden reproducir. Pesa 3,4 MB, lo que
# > está muy por debajo de cualquier límite razonable para un repositorio.

# %% [markdown]
# ### 3.2 El archivo `requirements.txt`
#
# Se genera a partir de las versiones **realmente presentes** en el entorno, no de una lista
# escrita a mano. Un archivo de dependencias que no corresponde al entorno que produjo los
# resultados no es reproducibilidad: es documentación inexacta.

# %%
def escribir_requirements(ruta, versiones):
    """
    Escribe requirements.txt a partir de las versiones observadas en el entorno.

    Parametros
    ----------
    ruta : Path
        Archivo de salida.
    versiones : dict
        Nombre de importacion -> version detectada (o None si falta).

    Retorna
    -------
    list of str
        Lineas escritas, para verificarlas.

    Lanza
    -----
    ValueError
        Si ninguna dependencia pudo detectarse.
    """
    lineas = []
    for nombre, version in versiones.items():
        if version is None:
            continue  # una libreria ausente no se declara: primero se instala
        paquete = NOMBRE_EN_PYPI.get(nombre, nombre)
        lineas.append(f"{paquete}=={version}")

    if not lineas:
        raise ValueError("No se detecto ninguna dependencia instalada.")

    # Se agregan las herramientas del flujo de trabajo, que no se importan desde el
    # codigo pero si forman parte del entorno reproducible.
    lineas += ["jupyterlab", "notebook", "ipykernel"]
    ruta.write_text("\n".join(sorted(lineas)) + "\n", encoding="utf-8")
    return sorted(lineas)


ARCHIVO_REQUIREMENTS = RAIZ / "requirements.txt"
requisitos = escribir_requirements(ARCHIVO_REQUIREMENTS, ENTORNO["versiones"])
print(ARCHIVO_REQUIREMENTS.relative_to(RAIZ).as_posix(), "\n")
print("\n".join(requisitos))
# Out:
# requirements.txt
#
# ipykernel
# jupyterlab
# matplotlib==3.9.4
# notebook
# numpy==2.0.2
# pandas==2.3.3
# scikit-learn==1.6.1

# %% [markdown]
# > **Atención.** Este archivo se generó desde las librerías presentes en el entorno de quien
# > ejecutó el cuaderno. Si un integrante lo ejecuta con versiones distintas, `requirements.txt`
# > cambiará y el cambio aparecerá en el `git diff`. Eso no es un defecto: es precisamente la
# > señal de que los entornos divergieron, y conviene resolverla antes de comparar resultados.

# %% [markdown]
# ## 4. Módulos: del cuaderno a `src/`
#
# Las funciones que ambos cuadernos necesitan se escriben una sola vez, en `src/utilidades.py`,
# y se importan. Duplicarlas entre la Fase 1 y la Fase 2 garantiza que en algún momento
# diverjan.
#
# El módulo incluye `construir_conjunto_trabajo()`, que implementa en una sola función el plan
# de saneamiento justificado en la sección 5.2. El cuaderno de la Fase 2 reconstruye ese
# conjunto paso a paso y a la vista, y al final contrasta su resultado con el de esta función:
# dos caminos independientes que deben coincidir.

# %%
CODIGO_MODULO = '''"""Utilidades compartidas del proyecto MCDI500 - Grupo 5.

Este modulo lo genera el cuaderno de la Fase 1 y lo importan las fases siguientes.
Conjunto: permisos de uso de via publica de San Francisco (DataSF, x8nh-xzn6).
"""

import re
from pathlib import Path

import numpy as np
import pandas as pd

MARCADORES = (".git", "requirements.txt", ".gitignore")

FORMATO_FECHA = "%m/%d/%Y"
FORMATO_SELLO = "%Y/%m/%d %I:%M:%S %p"
COLS_FECHA = ["Approved Date", "permit_start_date", "permit_end_date"]
COLS_COORDENADA = ["Latitude", "Longitude"]

# Columnas descartadas y su motivo. Ver seccion 5.2 del cuaderno de la Fase 1.
DESCARTES = {
    "CurbRampWork": "96,4% de nulos y un unico valor distinto: varianza cero",
    "bpa": "95,7% de nulos",
    "permit_address": "63,1% de nulos; redundante con streetname y cross streets",
    "Location": "geometria en texto, redundante con Latitude y Longitude",
    "the_geom": "geometria en texto, redundante con Latitude y Longitude",
    "X": "mismo punto en California State Plane; redundante",
    "Y": "mismo punto en California State Plane; redundante",
    "data_loaded_at": "sello de carga del portal, sin valor analitico",
    "Permit Type": "reemplazada por tipo_permiso agrupado",
    "Agent": "reemplazada por agente agrupado",
    "supervisor_district": "reemplazada por distrito como categorica",
    "AgentPhone": "dato de contacto, sin valor analitico",
    "24/7 Contact": "dato de contacto, sin valor analitico",
    "cnn": "identificador de segmento vial, sin valor explicativo",
}


class ProyectoError(Exception):
    """Error propio del proyecto: permite distinguirlo de los de las librerias."""


def normalizar_nombre(texto):
    """Convierte un nombre de columna a minusculas, sin espacios ni signos.

    Ejemplo
    -------
    >>> normalizar_nombre('Permit Type ')
    'permit_type'
    """
    if not isinstance(texto, str):
        raise ProyectoError(f"Se esperaba texto y se recibio {type(texto).__name__}.")
    limpio = texto.strip().lower()
    limpio = re.sub(r"[^a-z0-9]+", "_", limpio)   # todo lo que no sea letra o digito -> _
    return limpio.strip("_")


def normalizar_columnas(nombres):
    """Aplica normalizar_nombre a una lista y verifica que no se produzcan duplicados."""
    normalizados = [normalizar_nombre(n) for n in nombres]
    if len(set(normalizados)) != len(normalizados):
        raise ProyectoError("La normalizacion produjo nombres duplicados.")
    return normalizados


def localizar_raiz(inicio=None, marcadores=MARCADORES, niveles=5, respaldo=True):
    """Resuelve la raiz del proyecto. Ver seccion 3 del cuaderno de la Fase 1."""
    actual = Path(inicio or Path.cwd()).resolve()
    for candidata in [actual, *actual.parents][:niveles + 1]:
        if any((candidata / m).exists() for m in marcadores):
            return candidata, "estructurado"
    if respaldo:
        return actual, "plano"
    raise FileNotFoundError(f"No se encontro marcador de repositorio desde {actual}.")


def buscar_archivo(nombre, raiz=None, extra=()):
    """Busca un archivo en las ubicaciones canonicas y junto al cuaderno."""
    base = Path(raiz) if raiz is not None else localizar_raiz()[0]
    candidatos = [
        Path.cwd() / nombre, base / nombre,
        base / "data" / "raw" / nombre, base / "data" / "processed" / nombre,
        base / "docs" / nombre, *[Path(d) / nombre for d in extra],
    ]
    vistos = set()
    for ruta in candidatos:
        clave = str(ruta.resolve())
        if clave in vistos:
            continue
        vistos.add(clave)
        if ruta.exists():
            return ruta.resolve()
    return None


def leer_crudo(ruta):
    """Lee el CSV como texto, sin inferencia de tipos.

    La inferencia automatica es inaceptable en esta fuente: las coordenadas usan coma
    decimal y una parte de las fechas admite dos lecturas. Leer todo como texto obliga
    a declarar cada conversion de forma explicita.
    """
    return pd.read_csv(ruta, dtype=str)


def convertir_tipos(datos):
    """Convierte coordenadas, fechas y centinelas. No elimina filas ni columnas."""
    d = datos.copy()
    for col in COLS_COORDENADA:
        if col in d.columns:
            d[col] = pd.to_numeric(d[col].str.replace(",", ".", regex=False), errors="coerce")
    for col in COLS_FECHA:
        if col in d.columns:
            d[col] = pd.to_datetime(d[col], format=FORMATO_FECHA, errors="coerce")
    if "data_as_of" in d.columns:
        d["data_as_of"] = pd.to_datetime(d["data_as_of"], format=FORMATO_SELLO, errors="coerce")
    if "permit_zipcode" in d.columns:
        d["permit_zipcode"] = d["permit_zipcode"].replace("0", np.nan)   # centinela
    return d


def derivar_variables(datos, n_tipos=12, n_agentes=12):
    """Deriva el objetivo y las variables explicativas de la pregunta.

    Lanza
    -----
    KeyError
        Si falta alguna de las columnas necesarias para derivar.
    """
    requeridas = {"permit_start_date", "permit_end_date", "Approved Date",
                  "Permit Type", "Agent", "supervisor_district", "permit_number"}
    faltan = requeridas - set(datos.columns)
    if faltan:
        raise KeyError(f"Faltan columnas para derivar: {sorted(faltan)}")

    d = datos.copy()
    d["duracion_dias"] = (d["permit_end_date"] - d["permit_start_date"]).dt.days
    d["n_segmentos"] = d.groupby("permit_number")["permit_number"].transform("size")
    d["lag_aprob_inicio"] = (d["permit_start_date"] - d["Approved Date"]).dt.days
    d["anio_aprobacion"] = d["Approved Date"].dt.year
    d["mes_inicio"] = d["permit_start_date"].dt.month

    principales_tipo = d["Permit Type"].value_counts().head(n_tipos).index
    d["tipo_permiso"] = np.where(d["Permit Type"].isin(principales_tipo),
                                 d["Permit Type"], "Otros")
    principales_agente = d["Agent"].value_counts().head(n_agentes).index
    d["agente"] = np.where(d["Agent"].isin(principales_agente),
                           d["Agent"].fillna("Desconocido"), "Otros")
    d["distrito"] = d["supervisor_district"].fillna("Desconocido").astype(str)
    return d


def construir_conjunto_trabajo(datos_crudos):
    """Aplica el plan de saneamiento completo: tipos, derivadas, descartes y filtros.

    Implementa la decision justificada en la seccion 5.2 del cuaderno de la Fase 1.
    """
    d = derivar_variables(convertir_tipos(datos_crudos))
    d = d.drop(columns=[c for c in DESCARTES if c in d.columns])
    d = d.dropna(subset=["duracion_dias"])      # sin objetivo no hay caso analizable
    d = d.drop_duplicates()
    return d.reset_index(drop=True)


def clasificar_rol(serie):
    """Asigna el rol analitico de una variable segun las reglas del curso."""
    s = serie.dropna()
    if s.empty:
        return "vacia"
    unicos = s.nunique()
    proporcion = unicos / len(s)
    es_numerica = pd.api.types.is_numeric_dtype(s) and not pd.api.types.is_bool_dtype(s)
    if pd.api.types.is_datetime64_any_dtype(s):
        return "fecha"
    if unicos == 2:
        return "binaria"
    if es_numerica:
        entera = s.mod(1).eq(0).all()
        if entera and proporcion > 0.95 and len(s) > 50:
            return "identificador"
        if entera and (unicos <= 20 or proporcion < 0.05):
            return "discreta"
        return "continua"
    if pd.to_datetime(s.head(200), errors="coerce", format="mixed").notna().mean() > 0.9:
        return "fecha"
    if s.astype(str).str.len().mean() > 60:
        return "texto libre"
    if proporcion > 0.95 and len(s) > 50:
        return "identificador"
    return "nominal" if unicos <= 15 else "alta cardinalidad"


def contar_roles(datos):
    """Cuenta variables por rol analitico."""
    return pd.Series([clasificar_rol(datos[c]) for c in datos.columns]).value_counts().to_dict()


def perfilar(datos):
    """Devuelve rol, dtype, nulos y cardinalidad por columna."""
    return pd.DataFrame({
        "rol": [clasificar_rol(datos[c]) for c in datos.columns],
        "dtype": datos.dtypes.astype(str),
        "n_nulos": datos.isna().sum(),
        "pct_nulos": (datos.isna().mean() * 100).round(2),
        "n_unicos": datos.nunique(dropna=True),
    }, index=datos.columns)
'''

ARCHIVO_MODULO = DIR_SRC / "utilidades.py"
ARCHIVO_MODULO.write_text(CODIGO_MODULO, encoding="utf-8")
print("Módulo escrito en:", ARCHIVO_MODULO.relative_to(RAIZ).as_posix(),
      f"({ARCHIVO_MODULO.stat().st_size} bytes)")
# Out:
# Módulo escrito en: src/utilidades.py (8183 bytes)

# %% [markdown]
# Para importarlo hay que agregar `src/` a la lista de rutas donde Python busca módulos.
# `invalidate_caches` y `reload` permiten volver a ejecutar el cuaderno sin reiniciar el kernel:
# sin ellos, Python seguiría usando la versión del módulo que cargó la primera vez.

# %%
if str(DIR_SRC.resolve()) not in sys.path:
    sys.path.insert(0, str(DIR_SRC.resolve()))

importlib.invalidate_caches()
import utilidades                      # el módulo recién escrito
importlib.reload(utilidades)           # por si el cuaderno se vuelve a ejecutar

print("Importado:", utilidades.__name__, "desde", Path(utilidades.__file__).as_posix())
print(utilidades.normalizar_nombre("Permit Type "))
print(utilidades.normalizar_columnas(["Approved Date", "Cross Street 1", "24/7 Contact"]))
print("Funciones expuestas:", sorted(n for n in dir(utilidades)
                                     if not n.startswith("_")
                                     and callable(getattr(utilidades, n))))
# Out:
# Importado: utilidades desde /Users/ricardo/Desktop/Repositorios/proyecto-grupo5-mcdi500/src/utilidades.py
# permit_type
# ['approved_date', 'cross_street_1', '24_7_contact']
# Funciones expuestas: ['Path', 'ProyectoError', 'buscar_archivo', 'clasificar_rol', 'construir_conjunto_trabajo', 'contar_roles', 'convertir_tipos', 'derivar_variables', 'leer_crudo', 'localizar_raiz', 'normalizar_columnas', 'normalizar_nombre', 'perfilar']

# %% [markdown]
# ### 4.1 Pruebas del módulo (casos normal, límite y excepción)
#
# Tres tipos de caso por cada función relevante. La rúbrica los exige y, además, son lo que
# permite cambiar el módulo más adelante sin romper lo que ya funcionaba.

# %%
def probar_modulo():
    """Ejecuta las pruebas del modulo: casos normal, limite y excepciones."""
    import tempfile

    # --- Caso normal ---
    assert utilidades.normalizar_nombre("Approved Date") == "approved_date"
    assert utilidades.normalizar_columnas(["A B", "c-d"]) == ["a_b", "c_d"]
    assert utilidades.localizar_raiz(RAIZ)[0] == RAIZ
    print("[OK] Caso normal: normalización y localización de la raíz")

    # --- Caso limite: signos consecutivos, lista vacia y busqueda sin coincidencia ---
    assert utilidades.normalizar_nombre("  ¿24/7 Contact?  ") == "24_7_contact"
    assert utilidades.normalizar_columnas([]) == []
    assert utilidades.buscar_archivo("no_existe_jamas_12345.csv", RAIZ) is None
    print("[OK] Caso límite: signos, lista vacía y archivo inexistente")

    # --- Caso limite: carpeta sin marcador de repositorio ---
    with tempfile.TemporaryDirectory() as temporal:
        ruta, modo = utilidades.localizar_raiz(temporal, niveles=0)
        assert Path(ruta) == Path(temporal).resolve() and modo == "plano"
        (Path(temporal) / ".gitignore").touch()
        assert utilidades.localizar_raiz(temporal, niveles=0)[1] == "estructurado"
        print("[OK] Caso límite: respaldo sin marcador y detección con marcador")

        # --- Excepcion 1: sin marcador y sin respaldo ---
        (Path(temporal) / ".gitignore").unlink()
        try:
            utilidades.localizar_raiz(temporal, niveles=0, respaldo=False)
            raise AssertionError("debio lanzar FileNotFoundError")
        except FileNotFoundError as e:
            print(f"[OK] Excepción capturada (raíz): {str(e).split('.')[0]}")

    # --- Excepcion 2: tipo incorrecto ---
    try:
        utilidades.normalizar_nombre(42)
        raise AssertionError("debio lanzar ProyectoError")
    except utilidades.ProyectoError as e:
        print(f"[OK] Excepción capturada (tipo): {e}")

    # --- Excepcion 3: la normalizacion colapsa dos nombres en uno ---
    try:
        utilidades.normalizar_columnas(["Agent", " agent "])
        raise AssertionError("debio lanzar ProyectoError")
    except utilidades.ProyectoError as e:
        print(f"[OK] Excepción capturada (duplicados): {e}")

    # --- Excepcion 4: faltan columnas para derivar ---
    try:
        utilidades.derivar_variables(pd.DataFrame({"permit_number": [1]}))
        raise AssertionError("debio lanzar KeyError")
    except KeyError as e:
        print(f"[OK] Excepción capturada (columnas): {str(e)[:60]}...")

    print("\n[OK] 8/8 pruebas del módulo superadas")
    return True


_, ANEXO_G1 = capturar(probar_modulo)      # Anexo G del informe (Fase 1)
# Out:
# [OK] Caso normal: normalización y localización de la raíz
# [OK] Caso límite: signos, lista vacía y archivo inexistente
# [OK] Caso límite: respaldo sin marcador y detección con marcador
# [OK] Excepción capturada (raíz): No se encontro marcador de repositorio desde /private/var/folders/25/1d9z1__s1fl2f9r35bnxb_080000gn/T/tmp39qawsmf
# [OK] Excepción capturada (tipo): Se esperaba texto y se recibio int.
# [OK] Excepción capturada (duplicados): La normalizacion produjo nombres duplicados.
# [OK] Excepción capturada (columnas): "Faltan columnas para derivar: ['Agent', 'Approved Date', 'P...
#
# [OK] 8/8 pruebas del módulo superadas

# %% [markdown]
# > **Por qué una excepción propia.** `ProyectoError` hereda de `Exception` y permite
# > distinguir un fallo del proyecto de uno de pandas o de Python. Cuando el cuaderno falle
# > dentro de seis meses, la diferencia entre «se rompió algo» y «el módulo detectó que la
# > normalización iba a perder una columna» es lo que separa diez minutos de una tarde.

# %% [markdown]
# ## 5. Selección y ficha del conjunto de datos

# %% [markdown]
# ### 5.1 Procedencia
#
# Los metadatos provienen del portal oficial, no de la descripción de la descarga.
#
# **Cita en APA 7**, con fecha de recuperación porque la fuente cambia a diario:
#
# > San Francisco Public Works. (2026). *Active street-use permits* [Conjunto de datos].
# > DataSF. Recuperado el 9 de septiembre de 2026, de
# > https://data.sf.gov/City-Infrastructure/Active-Street-Use-Permits/x8nh-xzn6/about_data
#
# El portal declara además el criterio de inclusión, que resulta determinante para interpretar
# los resultados: se publican los permisos con estado activo o aprobado y, **solo para los tipos
# Excavation y TempOcc**, aquellos que no han superado su fecha de término.

# %%
FICHA = {
    "titulo": "Active Street-Use Permits",
    "identificador": "x8nh-xzn6",
    "inventario": "DPW-0022",
    "autor": "San Francisco Public Works",
    "plataforma": "DataSF",
    "url": "https://data.sf.gov/City-Infrastructure/Active-Street-Use-Permits/"
           "x8nh-xzn6/about_data",
    "licencia": "Open Data Commons Public Domain Dedication and License (PDDL) 1.0",
    "licencia_abierta": True,
    "publicado": "2025-01-17",
    "corte_declarado": "2026-09-09",     # se verifica contra data_as_of en la seccion 5.4
    "frecuencia": "Diaria",
    "descargado": "2026-09-09",
    "archivo": "Active_Street-Use_Permits_20260909.csv",
    "criterio_inclusion": (
        "Permisos con estado activo o aprobado. Para los tipos Excavation y TempOcc, "
        "unicamente aquellos que no han superado su fecha de termino."
    ),
    "historico": "Street-Use Permits (b6tj-gt35), sin filtro de vigencia",
    # Estructura del archivo TAL COMO SE DESCARGA, con los tipos ya convertidos.
    "filas": 6852,
    "columnas": 29,
    "roles": {"alta cardinalidad": 18, "fecha": 5, "nominal": 2, "continua": 2,
              "texto libre": 1, "binaria": 1, "discreta": 0, "ordinal": 0},
    "pct_nulos_max_variable": 96.44,     # CurbRampWork
    "pct_nulos_min_no_cero": 0.03,
}

for clave in ("titulo", "autor", "plataforma", "licencia", "corte_declarado",
              "frecuencia", "archivo"):
    print(f"  {clave:20}: {FICHA[clave]}")
print(f"  {'dimensiones':20}: {FICHA['filas']} filas x {FICHA['columnas']} columnas")
# Out:
#   titulo              : Active Street-Use Permits
#   autor               : San Francisco Public Works
#   plataforma          : DataSF
#   licencia            : Open Data Commons Public Domain Dedication and License (PDDL) 1.0
#   corte_declarado     : 2026-09-09
#   frecuencia          : Diaria
#   archivo             : Active_Street-Use_Permits_20260909.csv
#   dimensiones         : 6852 filas x 29 columnas

# %% [markdown]
# ### 5.2 Evaluación contra los criterios del curso
#
# El curso exige que el conjunto reúna una variedad mínima de roles analíticos y una presencia
# de faltantes que justifique el preprocesamiento. Se evalúa primero el archivo **tal como se
# descarga**.

# %%
CRITERIOS = {
    "filas": ("Filas", 2000, "Permite agrupar por categoria sin grupos vacios"),
    "columnas": ("Columnas", 12, "Asegura variedad de roles analiticos"),
    "continua": ("Numericas continuas", 2, "Escalamiento y valores atipicos"),
    "discreta": ("Numerica discreta", 1, "Obliga a decidir numero frente a categoria"),
    "nominal": ("Categoricas nominales", 2, "Codificacion One-Hot"),
    "ordinal_o_binaria": ("Binaria u ordinal", 1, "Codificacion con orden declarado"),
    "fecha": ("Fecha", 1, "Parseo y derivacion de variables temporales"),
    "alta_cardinalidad": ("Texto o alta cardinalidad", 1, "Normalizacion y agrupacion"),
}


def evaluar_criterios(ficha, criterios=CRITERIOS):
    """
    Contrasta una ficha de conjunto de datos con los minimos exigidos por el curso.

    Nota sobre el criterio de faltantes: el enunciado dice "alguna variable con >=1% de
    nulos", de modo que basta con que exista una. Se evalua por tanto contra el maximo
    observado y no contra el minimo, que exigiria que TODAS lo superaran.

    Lanza
    -----
    KeyError
        Si la ficha no declara el conteo de variables por rol.
    """
    if "roles" not in ficha:
        raise KeyError("La ficha debe declarar el conteo de variables por rol analitico.")
    r = ficha["roles"]
    obs = {
        "filas": ficha.get("filas", 0), "columnas": ficha.get("columnas", 0),
        "continua": r.get("continua", 0), "discreta": r.get("discreta", 0),
        "nominal": r.get("nominal", 0),
        "ordinal_o_binaria": r.get("ordinal", 0) + r.get("binaria", 0),
        "fecha": r.get("fecha", 0),
        "alta_cardinalidad": r.get("alta cardinalidad", 0) + r.get("texto libre", 0),
    }
    filas = [{"criterio": e, "minimo": m, "observado": obs[k],
              "cumple": "si" if obs[k] >= m else "NO", "por que se pide": motivo}
             for k, (e, m, motivo) in criterios.items()]
    mx = ficha.get("pct_nulos_max_variable", 0.0)
    filas.append({"criterio": "Alguna variable con >=1% de nulos", "minimo": 1.0,
                  "observado": mx, "cumple": "si" if mx >= 1.0 else "NO",
                  "por que se pide": "Un conjunto perfecto no tiene preprocesamiento que justificar"})
    filas.append({"criterio": "Ninguna variable sobre 60% de nulos", "minimo": 60.0,
                  "observado": mx, "cumple": "si" if mx <= 60.0 else "NO",
                  "por que se pide": "Por encima de eso la variable no es recuperable"})
    tabla = pd.DataFrame(filas)
    for col in ("minimo", "observado"):
        tabla[col] = tabla[col].map(lambda v: f"{v:g}")
    return tabla


evaluacion_archivo = evaluar_criterios(FICHA)
evaluacion_archivo
# Out:
#                               criterio minimo observado cumple  \
# 0                                Filas   2000      6852     si
# 1                             Columnas     12        29     si
# 2                  Numericas continuas      2         2     si
# 3                    Numerica discreta      1         0     NO
# 4                Categoricas nominales      2         2     si
# 5                    Binaria u ordinal      1         1     si
# 6                                Fecha      1         5     si
# 7            Texto o alta cardinalidad      1        19     si
# 8    Alguna variable con >=1% de nulos      1     96.44     si
# 9  Ninguna variable sobre 60% de nulos     60     96.44     NO
#
#                                      por que se pide
# 0    Permite agrupar por categoria sin grupos vacios
# 1               Asegura variedad de roles analiticos
# 2                    Escalamiento y valores atipicos
# 3         Obliga a decidir numero frente a categoria
# 4                               Codificacion One-Hot
# 5                   Codificacion con orden declarado
# 6        Parseo y derivacion de variables temporales
# 7                         Normalizacion y agrupacion
# 8  Un conjunto perfecto no tiene preprocesamiento...
# 9    Por encima de eso la variable no es recuperable

# %%
incumplidos_archivo = evaluacion_archivo.loc[
    evaluacion_archivo["cumple"] == "NO", "criterio"].tolist()
print(f"Archivo tal como se descarga: "
      f"{len(evaluacion_archivo) - len(incumplidos_archivo)}/{len(evaluacion_archivo)} criterios")
for x in incumplidos_archivo:
    print("  NO cumple:", x)
# Out:
# Archivo tal como se descarga: 8/10 criterios
#   NO cumple: Numerica discreta
#   NO cumple: Ninguna variable sobre 60% de nulos

# %% [markdown]
# > **Léase con atención el resultado.** El archivo **no cumple** dos criterios: no hay
# > ninguna variable numérica discreta, y tres columnas superan el 60 % de valores faltantes
# > —`CurbRampWork` con 96,4 %, `bpa` con 95,7 % y `permit_address` con 63,1 %—. Descubrirlo
# > aquí, y no en la Fase 2, es exactamente para lo que sirve evaluar el conjunto antes de
# > comprometerse con él.
# >
# > **El archivo tal como se descarga no es el conjunto de análisis.** Tres grupos de decisiones
# > lo separan del conjunto de trabajo:
# >
# > 1. **Conversión de tipos, nunca por inferencia.** Las coordenadas usan coma decimal y
# >    ninguna se interpreta como número al leer el archivo. En las fechas, una parte de los
# >    registros admite dos lecturas. La sección 5.4 lo mide.
# > 2. **Catorce columnas descartadas**, por cuatro motivos: exceso de faltantes, varianza nula,
# >    redundancia geométrica y ausencia de valor explicativo. El motivo de cada una está
# >    declarado en `utilidades.DESCARTES`.
# > 3. **Filtro de filas.** Solo se conservan los permisos con ambas fechas presentes, porque
# >    sin ellas la duración autorizada —la variable objetivo— no existe. Y se eliminan las
# >    filas exactamente duplicadas que quedan tras los descartes.
# >
# > *Enfoque descartado:* imputar las fechas ausentes para conservar los 6.852 registros.
# > Imputar la variable objetivo fabrica los casos que después se pretende explicar.
# >
# > Las derivaciones del plan aportan además las variables discretas que faltaban: la duración
# > en días, el número de segmentos por permiso, el retraso entre aprobación e inicio, el año de
# > aprobación y el mes de inicio.

# %% [markdown]
# ### 5.3 Diccionario de variables
#
# El diccionario declara dos atributos por variable. El **rol analítico** determina el
# preprocesamiento de la Fase 2. El **uso** determina si la variable participa en el análisis y
# en qué papel, y es el mecanismo que impide la fuga de información: se decide una vez aquí y
# las fases siguientes lo leen sin volver a decidirlo.

# %%
ARCHIVO = utilidades.buscar_archivo(FICHA["archivo"], RAIZ)

if ARCHIVO is None:
    crudo = trabajo = None
    print("[PENDIENTE] No se encontró", FICHA["archivo"])
    print("Descárguelo desde:", FICHA["url"])
    print("y guárdelo en    :", DIR_CRUDO.relative_to(RAIZ).as_posix())
else:
    crudo = utilidades.leer_crudo(ARCHIVO)
    trabajo = utilidades.construir_conjunto_trabajo(crudo)

    conv = utilidades.convertir_tipos(crudo)
    sin_objetivo = int((conv["permit_end_date"] - conv["permit_start_date"]).dt.days.isna().sum())
    duplicadas = crudo.shape[0] - sin_objetivo - trabajo.shape[0]

    print("Archivo            :", ARCHIVO.relative_to(RAIZ).as_posix())
    print("Crudo              :", crudo.shape)
    print("Sin ambas fechas   :", sin_objetivo, "registros descartados")
    print("Duplicados exactos :", duplicadas, "registros descartados")
    print("Conjunto de trabajo:", trabajo.shape)
    print("Permisos únicos    :", trabajo.permit_number.nunique())
    print("Columnas descartadas:", len(utilidades.DESCARTES))

FICHA_GRUPO = {
    "titulo": FICHA["titulo"] + " — conjunto de trabajo",
    "autor": FICHA["autor"],
    "plataforma": FICHA["plataforma"],
    "url": FICHA["url"],
    "licencia_abierta": FICHA["licencia_abierta"],
    "archivo": FICHA["archivo"],
    "filas": 6010,
    "columnas": 23,
    "roles": {"alta cardinalidad": 7, "discreta": 5, "fecha": 4, "nominal": 3,
              "continua": 2, "texto libre": 1, "binaria": 1, "ordinal": 0},
    "pct_nulos_max_variable": 38.47,     # Inspector
    "pct_nulos_min_no_cero": 0.05,       # analysis_neighborhood
}

evaluacion = evaluar_criterios(FICHA_GRUPO)
incumplidos = evaluacion.loc[evaluacion["cumple"] == "NO", "criterio"].tolist()

if trabajo is not None:
    # La ficha es una declaracion; aqui se comprueba contra el conjunto real.
    nulos = (trabajo.isna().mean() * 100).round(2)
    assert FICHA_GRUPO["filas"] == len(trabajo), "La ficha declara otro numero de filas."
    assert FICHA_GRUPO["columnas"] == trabajo.shape[1], "La ficha declara otro numero de columnas."
    assert abs(FICHA_GRUPO["pct_nulos_max_variable"] - nulos.max()) < 0.01
    print("\n[OK] La ficha declarada coincide con el conjunto de trabajo real")

print(f"\nConjunto de trabajo: {len(evaluacion) - len(incumplidos)}/{len(evaluacion)} criterios")
print("Incumplidos:", incumplidos or "ninguno")
evaluacion
# Out:
# Archivo            : data/raw/Active_Street-Use_Permits_20260909.csv
# Crudo              : (6852, 29)
# Sin ambas fechas   : 838 registros descartados
# Duplicados exactos : 4 registros descartados
# Conjunto de trabajo: (6010, 23)
# Permisos únicos    : 2139
# Columnas descartadas: 14
#
# [OK] La ficha declarada coincide con el conjunto de trabajo real
#
# Conjunto de trabajo: 10/10 criterios
# Incumplidos: ninguno
#                               criterio minimo observado cumple  \
# 0                                Filas   2000      6010     si
# 1                             Columnas     12        23     si
# 2                  Numericas continuas      2         2     si
# 3                    Numerica discreta      1         5     si
# 4                Categoricas nominales      2         3     si
# 5                    Binaria u ordinal      1         1     si
# 6                                Fecha      1         4     si
# 7            Texto o alta cardinalidad      1         8     si
# 8    Alguna variable con >=1% de nulos      1     38.47     si
# 9  Ninguna variable sobre 60% de nulos     60     38.47     si
#
#                                      por que se pide
# 0    Permite agrupar por categoria sin grupos vacios
# 1               Asegura variedad de roles analiticos
# 2                    Escalamiento y valores atipicos
# 3         Obliga a decidir numero frente a categoria
# 4                               Codificacion One-Hot
# 5                   Codificacion con orden declarado
# 6        Parseo y derivacion de variables temporales
# 7                         Normalizacion y agrupacion
# 8  Un conjunto perfecto no tiene preprocesamiento...
# 9    Por encima de eso la variable no es recuperable

# %%
DICCIONARIO = [
    # (variable, rol analitico, uso, descripcion)
    ("duracion_dias",         "discreta",          "objetivo",        "Duracion autorizada en dias: permit_end_date - permit_start_date"),
    ("tipo_permiso",          "nominal",           "explicativa",     "Tipo de permiso; 12 niveles principales + Otros"),
    ("analysis_neighborhood", "alta cardinalidad", "explicativa",     "Barrio de emplazamiento; 41 niveles"),
    ("agente",                "nominal",           "explicativa",     "Agente solicitante; 12 principales + Otros. NO es el organismo emisor"),
    ("anio_aprobacion",       "discreta",          "explicativa",     "Anio de aprobacion, derivado de Approved Date"),
    ("distrito",              "nominal",           "explicativa",     "Distrito del supervisor; 11 niveles + Desconocido"),
    ("n_segmentos",           "discreta",          "explicativa",     "Segmentos de calle que abarca el permiso; proxy del tamanio del proyecto"),
    ("lag_aprob_inicio",      "discreta",          "explicativa",     "Dias entre aprobacion e inicio; negativo en aprobaciones retroactivas"),
    ("mes_inicio",            "discreta",          "explicativa",     "Mes de inicio; estacionalidad"),
    ("Permit Purpose",        "texto libre",       "explicativa",     "Descripcion del proposito; 26,3% ausente y la ausencia es informativa"),
    ("Inspector",             "alta cardinalidad", "explicativa",     "Inspector municipal asignado; 38,5% ausente y la ausencia es informativa"),
    ("permit_zipcode",        "alta cardinalidad", "explicativa",     "Codigo postal; el valor 0 es centinela de ausencia"),
    ("Status",                "binaria",           "no_usada",        "Estado administrativo; no es un factor de la pregunta"),
    ("permit_number",         "alta cardinalidad", "grupo",           "Identificador del permiso; unidad de agrupacion para la particion"),
    ("permit_start_date",     "fecha",             "fuente_objetivo", "Componente del objetivo; no puede ser explicativa"),
    ("permit_end_date",       "fecha",             "fuente_objetivo", "Componente del objetivo; no puede ser explicativa"),
    ("Approved Date",         "fecha",             "fuente_derivada", "Origen de anio_aprobacion y lag_aprob_inicio"),
    ("data_as_of",            "fecha",             "trazabilidad",    "Sello de actualizacion del portal"),
    ("Latitude",              "continua",          "validacion",      "Latitud; validacion espacial y mapas de la Fase 4"),
    ("Longitude",             "continua",          "validacion",      "Longitud; validacion espacial y mapas de la Fase 4"),
    ("streetname",            "alta cardinalidad", "contexto",        "Calle principal del segmento"),
    ("Cross Street 1",        "alta cardinalidad", "contexto",        "Primera calle transversal"),
    ("Cross Street 2",        "alta cardinalidad", "contexto",        "Segunda calle transversal; 16,0% ausente"),
]

diccionario = pd.DataFrame(DICCIONARIO,
                           columns=["variable", "rol_analitico", "uso", "descripcion"])

OBJETIVO     = diccionario.loc[diccionario.uso == "objetivo", "variable"].item()
EXPLICATIVAS = diccionario.loc[diccionario.uso == "explicativa", "variable"].tolist()
GRUPO_VAR    = diccionario.loc[diccionario.uso == "grupo", "variable"].item()
PROHIBIDAS   = diccionario.loc[diccionario.uso.isin(["fuente_objetivo", "no_usada"]),
                               "variable"].tolist()

# Verificacion: el diccionario debe cubrir exactamente las columnas declaradas en la ficha.
assert len(diccionario) == FICHA_GRUPO["columnas"], "El diccionario no coincide con la ficha."
assert OBJETIVO not in EXPLICATIVAS
assert not set(PROHIBIDAS) & set(EXPLICATIVAS)
if trabajo is not None:
    assert set(diccionario.variable) == set(trabajo.columns), "Discrepancia de nombres."

print(diccionario["rol_analitico"].value_counts().to_string())
print(f"\nObjetivo: {OBJETIVO} | explicativas: {len(EXPLICATIVAS)} | "
      f"grupo: {GRUPO_VAR} | prohibidas: {PROHIBIDAS}")
diccionario
# Out:
# rol_analitico
# alta cardinalidad    7
# discreta             5
# fecha                4
# nominal              3
# continua             2
# texto libre          1
# binaria              1
#
# Objetivo: duracion_dias | explicativas: 11 | grupo: permit_number | prohibidas: ['Status', 'permit_start_date', 'permit_end_date']
#                  variable      rol_analitico              uso  \
# 0           duracion_dias           discreta         objetivo
# 1            tipo_permiso            nominal      explicativa
# 2   analysis_neighborhood  alta cardinalidad      explicativa
# 3                  agente            nominal      explicativa
# 4         anio_aprobacion           discreta      explicativa
# 5                distrito            nominal      explicativa
# 6             n_segmentos           discreta      explicativa
# 7        lag_aprob_inicio           discreta      explicativa
# 8              mes_inicio           discreta      explicativa
# 9          Permit Purpose        texto libre      explicativa
# 10              Inspector  alta cardinalidad      explicativa
# 11         permit_zipcode  alta cardinalidad      explicativa
# 12                 Status            binaria         no_usada
# 13          permit_number  alta cardinalidad            grupo
# 14      permit_start_date              fecha  fuente_objetivo
# 15        permit_end_date              fecha  fuente_objetivo
# 16          Approved Date              fecha  fuente_derivada
# 17             data_as_of              fecha     trazabilidad
# 18               Latitude           continua       validacion
# 19              Longitude           continua       validacion
# 20             streetname  alta cardinalidad         contexto
# 21         Cross Street 1  alta cardinalidad         contexto
# 22         Cross Street 2  alta cardinalidad         contexto
#
#                                           descripcion
# 0   Duracion autorizada en dias: permit_end_date -...
# 1     Tipo de permiso; 12 niveles principales + Otros
# 2                 Barrio de emplazamiento; 41 niveles
# 3   Agente solicitante; 12 principales + Otros. NO...
# 4       Anio de aprobacion, derivado de Approved Date
# 5   Distrito del supervisor; 11 niveles + Desconocido
# 6   Segmentos de calle que abarca el permiso; prox...
# 7   Dias entre aprobacion e inicio; negativo en ap...
# 8                       Mes de inicio; estacionalidad
# 9   Descripcion del proposito; 26,3% ausente y la ...
# 10  Inspector municipal asignado; 38,5% ausente y ...
# 11  Codigo postal; el valor 0 es centinela de ause...
# 12  Estado administrativo; no es un factor de la p...
# 13  Identificador del permiso; unidad de agrupacio...
# 14  Componente del objetivo; no puede ser explicativa
# 15  Componente del objetivo; no puede ser explicativa
# 16       Origen de anio_aprobacion y lag_aprob_inicio
# 17                  Sello de actualizacion del portal
# 18  Latitud; validacion espacial y mapas de la Fase 4
# 19  Longitud; validacion espacial y mapas de la Fa...
# 20                       Calle principal del segmento
# 21                          Primera calle transversal
# 22           Segunda calle transversal; 16,0% ausente

# %% [markdown]
# > **El rol no basta: hace falta el uso.** `permit_start_date` y `permit_end_date` tienen un
# > rol analítico impecable —son fechas— y sin embargo **no pueden usarse para explicar nada**,
# > porque la duración es su resta. Usarlas equivaldría a predecir una resta a partir de sus dos
# > sumandos. Esa distinción no cabe en la columna de rol, y por eso el diccionario declara una
# > columna adicional.
# >
# > Dos declaraciones más que respaldamos. `permit_number` es la **variable de
# > agrupación**, no un identificador descartable: un permiso abarca hasta 205 segmentos de calle
# > que comparten agente, propósito y ambas fechas, de modo que la partición de la Fase 2 debe
# > agrupar por él. Y `Latitude` y `Longitude` **no son explicativas**: la ubicación territorial
# > entra por `analysis_neighborhood`, que es interpretable en la respuesta; las coordenadas se
# > reservan para validar la consistencia del barrio.

# %% [markdown]
# ### 5.4 Comprobación del archivo y verificaciones de lectura
#
# Se contrasta la estructura real del archivo con la declarada y se verifican, con cifras, las
# tres afirmaciones sobre las que descansa el plan de saneamiento.

# %%
if crudo is not None:
    CORTE = conv["data_as_of"].max()
    print("Dimensiones reales :", crudo.shape)
    print("Declarado en ficha :", (FICHA["filas"], FICHA["columnas"]))
    print("Coincidencia       :",
          "[OK]" if crudo.shape == (FICHA["filas"], FICHA["columnas"]) else "[REVISAR]")
    print("Duplicados exactos en el crudo:", int(crudo.duplicated().sum()))
    print("Duplicados por (timestamp, permiso):",
          int(crudo.duplicated(subset=["permit_number", "cnn"]).sum()))
    print("\nCorte observado en data_as_of :", f"{CORTE:%Y-%m-%d %H:%M}")
    print("Corte declarado en la ficha   :", FICHA["corte_declarado"])
    print("Coincidencia                  :",
          "[OK]" if str(CORTE.date()) == FICHA["corte_declarado"]
          else "[REVISAR] actualice corte_declarado en FICHA")
    print("\nPerfil del conjunto de trabajo:")
    display(utilidades.perfilar(trabajo))
else:
    print("[PENDIENTE] Sin archivo no hay comprobación posible.")
# Out:
# Dimensiones reales : (6852, 29)
# Declarado en ficha : (6852, 29)
# Coincidencia       : [OK]
# Duplicados exactos en el crudo: 0
# Duplicados por (timestamp, permiso): 0
#
# Corte observado en data_as_of : 2026-09-09 03:15
# Corte declarado en la ficha   : 2026-09-09
# Coincidencia                  : [OK]
#
# Perfil del conjunto de trabajo:
#                                      rol           dtype  n_nulos  pct_nulos  \
# permit_number          alta cardinalidad          object        0       0.00
# streetname             alta cardinalidad          object        0       0.00
# Cross Street 1         alta cardinalidad          object        0       0.00
# Cross Street 2         alta cardinalidad          object      961      15.99
# Permit Purpose               texto libre          object     1581      26.31
# Approved Date                      fecha  datetime64[ns]        4       0.07
# Status                           binaria          object        0       0.00
# permit_zipcode         alta cardinalidad          object      817      13.59
# permit_start_date                  fecha  datetime64[ns]        0       0.00
# permit_end_date                    fecha  datetime64[ns]        0       0.00
# Inspector              alta cardinalidad          object     2312      38.47
# Latitude                        continua         float64        0       0.00
# Longitude                       continua         float64        0       0.00
# analysis_neighborhood  alta cardinalidad          object        3       0.05
# data_as_of                         fecha  datetime64[ns]        0       0.00
# duracion_dias                   discreta         float64        0       0.00
# n_segmentos                     discreta           int64        0       0.00
# lag_aprob_inicio                discreta         float64        4       0.07
# anio_aprobacion                 discreta         float64        4       0.07
# mes_inicio                      discreta         float64        0       0.00
# tipo_permiso                     nominal          object        0       0.00
# agente                           nominal          object        0       0.00
# distrito                         nominal          object        0       0.00
#
#                        n_unicos
# permit_number              2139
# streetname                  873
# Cross Street 1             1352
# Cross Street 2             1276
# Permit Purpose              887
# Approved Date               645
# Status                        2
# permit_zipcode               29
# permit_start_date           685
# permit_end_date             217
# Inspector                    44
# Latitude                   5150
# Longitude                  5150
# analysis_neighborhood        41
# data_as_of                  170
# duracion_dias               231
# n_segmentos                  58
# lag_aprob_inicio            174
# anio_aprobacion              11
# mes_inicio                   12
# tipo_permiso                 11
# agente                       13
# distrito                     12

# %% [markdown]
# **Verificación 1 · las coordenadas usan coma decimal.**

# %%
if crudo is not None:
    for col in ["Latitude", "Longitude", "X", "Y"]:
        directo = pd.to_numeric(crudo[col], errors="coerce")
        corregido = pd.to_numeric(crudo[col].str.replace(",", ".", regex=False), errors="coerce")
        print(f"  {col:10} parseo directo: {directo.notna().sum():5} valores | "
              f"con coma->punto: {corregido.notna().sum():5}")
    print("\n  Consecuencia de no corregirlo: el clasificador de roles asigna a Longitude")
    print(f"  el rol {utilidades.clasificar_rol(crudo['Longitude'])!r}, porque '-122,41...'")
    print("  sobrevive al intento de conversion temporal en cascada. El perfil de la base")
    print("  entera queda irreconocible.")
# Out:
#   Latitude   parseo directo:     0 valores | con coma->punto:  6852
#   Longitude  parseo directo:     0 valores | con coma->punto:  6852
#   X          parseo directo:     1 valores | con coma->punto:  6844
#   Y          parseo directo:     1 valores | con coma->punto:  6844
#
#   Consecuencia de no corregirlo: el clasificador de roles asigna a Longitude
#   el rol 'alta cardinalidad', porque '-122,41...'
#   sobrevive al intento de conversion temporal en cascada. El perfil de la base
#   entera queda irreconocible.

# %% [markdown]
# **Verificación 2 · las fechas admiten dos lecturas.** Conviene separar dos preguntas que
# suelen confundirse: si el formato es consistente, y cuántos registros son realmente ambiguos.

# %%
if crudo is not None:
    filas = []
    for col in utilidades.COLS_FECHA:
        s = crudo[col].dropna()
        mes_dia = pd.to_datetime(s, format=utilidades.FORMATO_FECHA, errors="coerce")
        dia_mes = pd.to_datetime(s, format="%d/%m/%Y", errors="coerce")
        ambas = mes_dia.notna() & dia_mes.notna()
        filas.append({
            "variable": col,
            "parseadas": int(mes_dia.notna().sum()),
            "NaT": int(mes_dia.isna().sum()),
            "1er campo > 12": int((s.str.slice(0, 2).astype(int) > 12).sum()),
            "legibles de ambas formas": int(ambas.sum()),
            "% ambiguas": round(float(ambas.mean() * 100), 1),
            "cambian al invertir": int((ambas & (mes_dia != dia_mes)).sum()),
        })
    comprobacion_fechas = pd.DataFrame(filas)
    display(comprobacion_fechas)
    print("A · Consistencia: ningun registro tiene el primer campo mayor que 12. Si alguno")
    print("    lo tuviera, estaria en formato dia/mes y la columna seria heterogenea.")
    print("    El formato mes/dia/anio queda verificado, no supuesto.")
    print("B · Ambiguedad real: una fecha admite las dos lecturas solo cuando el SEGUNDO")
    print("    campo tambien es <= 12. Ocurre entre el 25% y el 41%, no en todos.")
# Out:
#             variable  parseadas  NaT  1er campo > 12  \
# 0      Approved Date       6834    0               0
# 1  permit_start_date       6017    0               0
# 2    permit_end_date       6141    0               0
#
#    legibles de ambas formas  % ambiguas  cambian al invertir
# 0                      2480        36.3                 2392
# 1                      2473        41.1                 2257
# 2                      1554        25.3                 1439
# A · Consistencia: ningun registro tiene el primer campo mayor que 12. Si alguno
#     lo tuviera, estaria en formato dia/mes y la columna seria heterogenea.
#     El formato mes/dia/anio queda verificado, no supuesto.
# B · Ambiguedad real: una fecha admite las dos lecturas solo cuando el SEGUNDO
#     campo tambien es <= 12. Ocurre entre el 25% y el 41%, no en todos.

# %%
if crudo is not None:
    filas = []
    for col in utilidades.COLS_FECHA:
        s = crudo[col].dropna()
        primero = s.iloc[0]
        explicito = pd.to_datetime(s, format=utilidades.FORMATO_FECHA, errors="coerce")
        with warnings.catch_warnings(record=True) as avisos:
            warnings.simplefilter("always")
            inferido = pd.to_datetime(s, dayfirst=True, errors="coerce")
        filas.append({
            "variable": col,
            "primer valor": primero,
            "primer valor ambiguo": "si" if int(primero.split("/")[1]) <= 12 else "no",
            "la libreria advierte": "si" if avisos else "NO",
            "NaT introducidos": int(inferido.isna().sum()),
            "registros alterados": int((explicito.notna() & inferido.notna()
                                        & (explicito != inferido)).sum()),
        })
    efecto_inferencia = pd.DataFrame(filas)
    display(efecto_inferencia)
    print("El formato se deduce del PRIMER valor de la columna, y el patron es contraintuitivo:")
    print("  · Primer valor no ambiguo -> dedujo bien, ignoro la opcion pedida y lo advirtio.")
    print("  · Primer valor ambiguo    -> obedecio EN SILENCIO y aplico el formato invertido")
    print("    a toda la columna.")
    print("\nLa columna en la que la libreria no advirtio nada es la que corrompio.")
    print("De ahi la decision del plan: el formato se declara, nunca se deduce.")
# Out:
#             variable primer valor primer valor ambiguo la libreria advierte  \
# 0      Approved Date   04/15/2026                   no                   si
# 1  permit_start_date   05/01/2026                   si                   NO
# 2    permit_end_date   10/28/2026                   no                   si
#
#    NaT introducidos  registros alterados
# 0                 0                    0
# 1              3544                 2257
# 2                 0                    0
# El formato se deduce del PRIMER valor de la columna, y el patron es contraintuitivo:
#   · Primer valor no ambiguo -> dedujo bien, ignoro la opcion pedida y lo advirtio.
#   · Primer valor ambiguo    -> obedecio EN SILENCIO y aplico el formato invertido
#     a toda la columna.
#
# La columna en la que la libreria no advirtio nada es la que corrompio.
# De ahi la decision del plan: el formato se declara, nunca se deduce.

# %% [markdown]
# **Verificación 3 · el sesgo de selección de la fuente.** El portal publica solo permisos
# vigentes, de modo que un permiso corto iniciado hace años ya salió del registro y uno largo
# sigue dentro. Si el mecanismo opera, la duración **mínima** observada debe crecer con la
# antigüedad del inicio.

# %%
if trabajo is not None:
    t = trabajo.copy()
    t["antiguedad"] = (CORTE - t.permit_start_date).dt.days
    iniciados = t[t.antiguedad >= 0]
    tramos = pd.cut(iniciados.antiguedad, bins=[0, 90, 365, 730, 1825, 100000],
                    labels=["<3 meses", "3-12 meses", "1-2 anios", "2-5 anios", ">5 anios"],
                    right=False)
    tabla_sesgo = (iniciados.assign(tramo=tramos)
                   .groupby("tramo", observed=True)["duracion_dias"]
                   .agg(n="count", minima="min", mediana="median").round(0))
    display(tabla_sesgo)

    sujetos = ["Excavation", "TempOccup"]
    m = t.tipo_permiso.isin(sujetos)
    vencidos = t[t.permit_end_date < CORTE]
    print(f"Tipos sujetos al filtro estricto : {int(m.sum())} registros ({m.mean():.1%})")
    print(f"Ya vencidos pero aun listados    : {len(vencidos)} "
          f"({int(vencidos.tipo_permiso.isin(sujetos).sum())} de esos tipos)")
    print("\nEl piso de la duracion sube con la antiguedad: esa es la firma del mecanismo.")
    print("Los vencidos que permanecen son rezago de actualizacion del portal, no una")
    print("contradiccion con su documentacion.")
# Out:
#                n  minima  mediana
# tramo
# <3 meses    1810     2.0     66.0
# 3-12 meses  1497    98.0    364.0
# 1-2 anios    993   437.0    587.0
# 2-5 anios     51   997.0   3939.0
# >5 anios    1107   591.0   3939.0
# Tipos sujetos al filtro estricto : 4343 registros (72.3%)
# Ya vencidos pero aun listados    : 10 (7 de esos tipos)
#
# El piso de la duracion sube con la antiguedad: esa es la firma del mecanismo.
# Los vencidos que permanecen son rezago de actualizacion del portal, no una
# contradiccion con su documentacion.

# %% [markdown]
# **Verificación 4 · la ausencia es informativa.** Antes de decidir cómo tratar los valores
# faltantes hay que saber si su ausencia significa algo. Imputar una ausencia informativa borra
# la información que contiene.

# %%
if trabajo is not None:
    filas = []
    for col in ["Permit Purpose", "Inspector", "Cross Street 2", "permit_zipcode"]:
        presente = trabajo.loc[trabajo[col].notna(), OBJETIVO]
        ausente = trabajo.loc[trabajo[col].isna(), OBJETIVO]
        filas.append({
            "variable": col,
            "pct_ausente": round(trabajo[col].isna().mean() * 100, 1),
            "mediana_presente": round(presente.median()),
            "mediana_ausente": round(ausente.median()),
            "razon": round(ausente.median() / presente.median(), 2),
        })
    ausencia = pd.DataFrame(filas)
    display(ausencia)
    print("En Permit Purpose e Inspector la ausencia se asocia a permisos mucho mas largos:")
    print("NO se imputan, se codifican como categoria explicita. En las otras dos la razon")
    print("ronda 1 y la ausencia no aporta senal; ahi imputar es defendible.")
    print("La Fase 2 desarrolla ambos casos con cifras.")
# Out:
#          variable  pct_ausente  mediana_presente  mediana_ausente  razon
# 0  Permit Purpose         26.3               452             3934   8.70
# 1       Inspector         38.5               459              675   1.47
# 2  Cross Street 2         16.0               478              521   1.09
# 3  permit_zipcode         13.6               478              487   1.02
# En Permit Purpose e Inspector la ausencia se asocia a permisos mucho mas largos:
# NO se imputan, se codifican como categoria explicita. En las otras dos la razon
# ronda 1 y la ausencia no aporta senal; ahi imputar es defendible.
# La Fase 2 desarrolla ambos casos con cifras.

# %% [markdown]
# ## 6. Control de versiones
#
# Se consulta el estado real del repositorio. Si Git no está instalado o la carpeta todavía no
# es un repositorio, el cuaderno informa el hecho en lugar de fallar: la Fase 1 debe poder
# ejecutarse antes y después de inicializarlo.

# %%
def git(*argumentos):
    """
    Ejecuta un comando de Git y devuelve su salida como texto.

    Retorna
    -------
    (bool, str)
        Exito de la ejecucion y salida (o mensaje de error).
    """
    if shutil.which("git") is None:
        return False, "Git no está instalado o no está en el PATH."
    try:
        proceso = subprocess.run(["git", *argumentos], cwd=str(RAIZ),
                                 capture_output=True, text=True, timeout=20)
    except (OSError, subprocess.SubprocessError) as e:
        return False, f"No se pudo ejecutar Git: {e}"
    if proceso.returncode != 0:
        # stderr trae el motivo real; se devuelve tal cual para no ocultarlo.
        return False, proceso.stderr.strip() or "Git terminó con error."
    return True, proceso.stdout.strip()


ok, salida = git("--version")
print("Git                :", salida if ok else f"[AVISO] {salida}")

for clave in ("user.name", "user.email"):
    ok_cfg, valor = git("config", "--get", clave)
    estado = valor if ok_cfg and valor else "[FALTA] configúrelo con git config --global"
    print(f"{clave:19}:", estado)
# Out:
# Git                : git version 2.39.3 (Apple Git-146)
# user.name          : RJaramilloP
# user.email         : 153374817+RJaramilloP@users.noreply.github.com

# %% [markdown]
# > **Atención.** El correo configurado en Git debe ser **el mismo** de la cuenta de GitHub.
# > Si no coincide, los *commits* aparecen sin autor asociado y el criterio de contribuciones
# > individuales se pierde sin que nadie lo note hasta que ya no hay tiempo de corregirlo, porque
# > arreglarlo después obliga a reescribir el historial.

# %%
es_repo, _ = git("rev-parse", "--is-inside-work-tree")


def reportar_git():
    """Imprime el estado del repositorio: rama, commits, autores y remoto."""

    if es_repo:
        ok_rama, rama = git("rev-parse", "--abbrev-ref", "HEAD")
        print("Rama actual        :", rama if ok_rama else "sin commits todavía")

        ok_log, log = git("log", "--oneline", "-5")
        print("\nÚltimos commits")
        print(log if ok_log and log else "  (todavía no hay commits)")

        ok_aut, autores = git("shortlog", "-sne", "HEAD")
        print("\nContribuciones por integrante")
        print(autores if ok_aut and autores else "  (sin datos)")
        n_autores = len([l for l in (autores or "").splitlines() if l.strip()])
        if n_autores and n_autores < len(PROYECTO["integrantes"]):
            print(f"[ATENCIÓN] {n_autores} autor(es) frente a "
                  f"{len(PROYECTO['integrantes'])} integrantes declarados.")

        # --porcelain da una salida estable, pensada para ser leida por un programa.
        ok_st, estado = git("status", "--porcelain")
        pendientes = [l for l in estado.splitlines() if l.strip()] if ok_st else []
        print(f"\nArchivos con cambios sin registrar: {len(pendientes)}")
        for linea in pendientes[:10]:
            print("  ", linea)

        ok_rem, remoto = git("remote", "-v")
        print("\nRemoto             :", remoto.splitlines()[0] if ok_rem and remoto
              else "[FALTA] agregue el remoto con git remote add origin URL")
    else:
        print("[PENDIENTE] Esta carpeta todavía no es un repositorio Git.")
        print("Desde la terminal, en la raíz del proyecto:")
        print("  git init")
        print("  git add .gitignore requirements.txt README.md")
        print('  git commit -m "docs: estructura inicial del proyecto"')


_, ANEXO_B = capturar(reportar_git)         # Anexo B del informe
# Out:
# Rama actual        : main
#
# Últimos commits
# c27e38c fix: Cambio de nombre de cuaderno F2 y re-ejecución de ambos cuadernos para validación y cierre de actividad
# cc1d369 docs: Se ejecuta por última vez cuaderno F1 para actualizar datos de control de versiones y estructura.
# 6c653df fix: Implementación de código final de F2 con generación de anexos y set de datos procesados
# c0f373b fix: Cierre teórico y de estructura de cuaderno F2 (Código de verificación de anexos pendiente)
# bd0b5a0 fix: Se completa la etapa de verificación y aplicación de recursividad en metadatos
#
# Contribuciones por integrante
# 19	RJaramilloP <153374817+RJaramilloP@users.noreply.github.com>
#     16	Marco30101994-Unab <327074150+Marco30101994-Unab@users.noreply.github.com>
#     12	belenfassler <102735967+belenfassler@users.noreply.github.com>
#
# Archivos con cambios sin registrar: 3
#    M F1/notebooks/S1_F1_Definicion.ipynb
#     M requirements.txt
#    ?? Untitled.ipynb
#
# Remoto             : origin	https://github.com/RJaramilloP/proyecto-grupo5-mcdi500.git (fetch)

# %% [markdown]
# **Convención de *commits* del curso.** Los prefijos `docs`, `data`, `feat` y `fix`
# permiten leer el historial sin abrir cada cambio. Para esta fase, los *commits* proyectados
# son: `feat: entorno y estructura del proyecto`, `data: conjunto original versionado`,
# `docs: diccionario de variables y ficha del conjunto` y `fix: parseo explícito de fechas`.

# %% [markdown]
# ## 7. Validación técnica de la fase
#
# Todo lo que las secciones anteriores afirman se comprueba aquí de una vez. Si algo falla, la
# función lanza `AssertionError` y el cuaderno se detiene antes de persistir nada.

# %%
def validar_fase1(raiz, config, ficha, diccionario):
    """
    Comprueba que la Fase 1 dejo lo que la rubrica exige.
    Lanza AssertionError si alguna comprobacion falla.
    """
    print("VALIDACION DE LA FASE 1")
    print("-" * 45)

    # 1. Estructura de carpetas
    esperadas = ["data/raw", "data/processed", "docs", "src", "F1", "F2", "F3", "F4"]
    faltan = [c for c in esperadas if not (raiz / c).is_dir()]
    assert not faltan, f"Faltan carpetas: {faltan}"
    print(f"[OK] Estructura completa ({len(esperadas)} carpetas)")

    # 2. Artefactos del entorno reproducible
    for nombre in (".gitignore", "requirements.txt"):
        archivo = raiz / nombre
        assert archivo.exists(), f"Falta {nombre}."
        assert archivo.stat().st_size > 0, f"{nombre} esta vacio."
        print(f"[OK] {nombre} presente ({archivo.stat().st_size} bytes)")

    # 3. Definicion del problema
    for clave in ("titulo", "problematica", "objetivo_general", "objetivos_especificos"):
        assert config.get(clave), f"La configuracion no declara '{clave}'."
    assert len(config["objetivos_especificos"]) >= 3, "Se esperan al menos tres objetivos."
    print("[OK] Definición del problema completa")

    # 4. Coherencia entre ficha y diccionario
    assert len(diccionario) == ficha["columnas"], "Diccionario y ficha no coinciden."
    roles_declarados = set(diccionario["rol_analitico"])
    assert roles_declarados, "El diccionario no declara roles analiticos."
    print(f"[OK] Diccionario coherente ({len(diccionario)} variables, "
          f"{len(roles_declarados)} roles)")

    # 5. Control de fugas: ninguna variable prohibida entre las explicativas
    explicativas = set(diccionario.loc[diccionario.uso == "explicativa", "variable"])
    prohibidas = set(diccionario.loc[diccionario.uso.isin(["fuente_objetivo", "no_usada"]),
                                     "variable"])
    assert not explicativas & prohibidas, "Una variable prohibida figura como explicativa."
    print(f"[OK] Sin fugas declaradas ({len(prohibidas)} variables excluidas)")

    # 6. Modulo importable
    assert (raiz / "src" / "utilidades.py").exists(), "Falta el modulo src/utilidades.py."
    for funcion in ("normalizar_columnas", "construir_conjunto_trabajo", "localizar_raiz"):
        assert callable(getattr(utilidades, funcion, None)), \
            f"El modulo no expone {funcion}."
    print("[OK] Módulo src/utilidades.py importable y completo")

    # 7. El conjunto de trabajo supera los criterios del curso
    assert not incumplidos, f"El conjunto incumple: {incumplidos}"
    print(f"[OK] Conjunto de trabajo: {len(evaluacion)}/{len(evaluacion)} criterios")

    print(f"\n[INFO] Conjunto declarado: {ficha['titulo']}")
    print(f"[INFO] Archivo descargado: {'sí' if ARCHIVO is not None else 'todavía no'}")
    return True


validar_fase1(RAIZ, PROYECTO, FICHA_GRUPO, diccionario)
# Out:
# VALIDACION DE LA FASE 1
# ---------------------------------------------
# [OK] Estructura completa (8 carpetas)
# [OK] .gitignore presente (270 bytes)
# [OK] requirements.txt presente (95 bytes)
# [OK] Definición del problema completa
# [OK] Diccionario coherente (23 variables, 7 roles)
# [OK] Sin fugas declaradas (3 variables excluidas)
# [OK] Módulo src/utilidades.py importable y completo
# [OK] Conjunto de trabajo: 10/10 criterios
#
# [INFO] Conjunto declarado: Active Street-Use Permits — conjunto de trabajo
# [INFO] Archivo descargado: sí
# True

# %% [markdown]
# ## 8. Vinculación con el mapa conceptual
#
# La tabla recoge **los 38 nodos del mapa conceptual entregado por el Grupo 5**, literalmente y
# en su orden: los 25 de la página 1, agrupados por rama, y los 13 de la página 2, entre etapas
# del flujo y ciclo colaborativo. De cada uno se indica dónde se materializó en el avance, con
# qué evidencia verificable, y cuáles quedan proyectados a fases posteriores.

# %%
VINCULACION = [
    # (pagina, rama, nodo del mapa, donde se materializa, evidencia, estado)
    ("P1", "1 · Problemática y datos", "Pregunta de investigación", "F1 §1 · PROYECTO['preguntas']", "Enunciado aprobado por el docente", "Materializado"),
    ("P1", "1 · Problemática y datos", "Variable objetivo (duracion_dias)", "F1 §5.3 · diccionario", "duracion_dias = permit_end_date - permit_start_date", "Materializado"),
    ("P1", "1 · Problemática y datos", "Factores explicativos", "F1 §5.3 · metadatos_fase1.json", "Nueve variables explicativas declaradas", "Materializado"),
    ("P1", "1 · Problemática y datos", "Fuente de datos (DataSF x8nh-xzn6)", "F1 §5.1 · FICHA", "Licencia PDDL 1.0; corte verificado 2026-09-09", "Materializado"),
    ("P1", "1 · Problemática y datos", "Exploración inicial", "F1 §5.2 y §5.4", "Perfil por columna, roles y faltantes", "Materializado"),
    ("P1", "1 · Problemática y datos", "Limitación declarada", "F1 §1 y §5.4", "docs/sesgo_seleccion.csv: mínimo creciente 2→98→437→997", "Materializado"),
    ("P1", "2 · Entorno reproducible", "Python 3.x", "F1 §2 · verificar_entorno", "Intérprete y plataforma registrados", "Materializado"),
    ("P1", "2 · Entorno reproducible", "Entorno virtual .venv", "F1 §2 · verificar_entorno", "Campo entorno_virtual en los metadatos", "Materializado"),
    ("P1", "2 · Entorno reproducible", "requirements.txt", "F1 §3.2 · escribir_requirements", "Generado desde las versiones instaladas", "Materializado"),
    ("P1", "2 · Entorno reproducible", "Semilla fija", "F1 §0 y F2 §1", "SEMILLA = 42 en ambos cuadernos y en los metadatos", "Materializado"),
    ("P1", "2 · Entorno reproducible", "Rutas relativas", "F1 §3 · localizar_raiz", "Pruebas de la §4.1; ejecutado desde F1/notebooks/", "Materializado"),
    ("P1", "3 · Herramientas científicas", "Jupyter Notebook", "F1 y F2 completos", "Numeración de ejecución continua, sin errores", "Materializado"),
    ("P1", "3 · Herramientas científicas", "Librerías", "F1 §2 · DEPENDENCIAS", "pandas, numpy, matplotlib, scikit-learn con versión fijada", "Materializado"),
    ("P1", "3 · Herramientas científicas", "Git", "F1 §6 · función git()", "Rama, commits y estado del árbol", "Materializado"),
    ("P1", "3 · Herramientas científicas", "GitHub", "Repositorio remoto", "URL citada en el informe", "Materializado"),
    ("P1", "4 · Estructura del entorno técnico", "Repositorio", "Raíz del proyecto", "proyecto-grupo5-mcdi500", "Materializado"),
    ("P1", "4 · Estructura del entorno técnico", "Carpetas", "F1 §3", "data/raw, data/processed, docs, src, F1-F4", "Materializado"),
    ("P1", "4 · Estructura del entorno técnico", "Archivos clave", "F1 §3.1, §3.2 y §9", "README.md, requirements.txt, .gitignore", "Materializado"),
    ("P1", "4 · Estructura del entorno técnico", "Commits proyectados", "F1 §6 · convención", "Prefijos feat, data, docs y fix", "Materializado"),
    ("P1", "4 · Estructura del entorno técnico", "Criterios de versionamiento", "README y F1 §6", "Rama por integrante; datos crudos inmutables", "Materializado"),
    ("P1", "5 · Documentación científica", "Celdas narrativas", "F1 y F2", "Cada decisión precedida de su justificación", "Materializado"),
    ("P1", "5 · Documentación científica", "Celdas de código", "F1 y F2", "Funciones con docstring y pruebas", "Materializado"),
    ("P1", "5 · Documentación científica", "Diccionario de variables", "F1 §5.3", "docs/diccionario_variables.csv, 23 variables", "Materializado"),
    ("P1", "5 · Documentación científica", "Metadatos por fase", "F1 §9 y F2 §9", "metadatos_fase1.json y metadatos_fase2.json", "Materializado"),
    ("P1", "5 · Documentación científica", "Informe técnico", "Entregable de la Sumativa 1", "Ocho apartados, bibliografía APA 7 y anexos", "Materializado"),
    ("P2", "Flujo reproducible", "1. Obtener y registrar la fuente", "F1 §5.1 y §5.4", "data/raw intacto; comprobación en F2", "Materializado"),
    ("P2", "Flujo reproducible", "2. Configurar el entorno", "F1 §2 y §3.2", "requirements.txt generado desde el entorno", "Materializado"),
    ("P2", "Flujo reproducible", "3. Estructurar y versionar", "F1 §3 y §6", "Árbol creado y validado; consultas a git", "Materializado"),
    ("P2", "Flujo reproducible", "4. Definir variables y roles", "F1 §5.3 y §9", "Diccionario y metadatos como contrato entre fases", "Materializado"),
    ("P2", "Flujo reproducible", "5. Limpiar y transformar", "F2 §3 a §7", "data/processed con los conjuntos limpio y procesado", "Materializado"),
    ("P2", "Flujo reproducible", "6. Validar", "F2 §8", "docs/validacion_fase2.csv, 12 de 12 comprobaciones", "Materializado"),
    ("P2", "Flujo reproducible", "7. Modelar, analizar y comunicar", "Fases 3 y 4", "Modelado, eficiencia algorítmica y hallazgos", "Proyectado"),
    ("P2", "Ciclo colaborativo", "Rama por integrante", "Historial del repositorio", "Ramas nominales antes de integrar", "Materializado"),
    ("P2", "Ciclo colaborativo", "Editar el notebook", "F1 y F2", "Celda narrativa acompañada de celda de código", "Materializado"),
    ("P2", "Ciclo colaborativo", "Ejecutar de principio a fin sin errores", "F1 y F2", "Numeración de ejecución continua, cero errores", "Materializado"),
    ("P2", "Ciclo colaborativo", "Commit con prefijo", "Historial del repositorio", "feat, data, docs y fix", "Materializado"),
    ("P2", "Ciclo colaborativo", "Push y pull request", "Repositorio remoto", "Revisión previa a la integración", "Materializado"),
    ("P2", "Ciclo colaborativo", "Integrar a la rama principal", "Historial del repositorio", "git shortlog -sne con los tres integrantes", "Materializado"),
]

vinculacion = pd.DataFrame(VINCULACION, columns=["pagina", "rama", "nodo",
                                                 "materializado_en", "evidencia", "estado"])

# Ningun nodo del mapa puede quedar sin evidencia: eso es lo que la rubrica revisa.
assert vinculacion["evidencia"].str.strip().ne("").all(), "Hay nodos sin evidencia."
proyectados = vinculacion.loc[vinculacion.estado == "Proyectado", "nodo"].tolist()

print(f"Nodos del mapa conceptual : {len(vinculacion)}")
print(f"  página 1 (jerarquía)    : {int((vinculacion.pagina == 'P1').sum())}")
print(f"  página 2 (flujo y ciclo): {int((vinculacion.pagina == 'P2').sum())}")
print(f"Materializados            : {int((vinculacion.estado == 'Materializado').sum())}")
print(f"Proyectados a F3 y F4     : {len(proyectados)} -> {proyectados}\n")
print(vinculacion.groupby(["pagina", "rama"], observed=True).size().to_string())
vinculacion
# Out:
# Nodos del mapa conceptual : 38
#   página 1 (jerarquía)    : 25
#   página 2 (flujo y ciclo): 13
# Materializados            : 37
# Proyectados a F3 y F4     : 1 -> ['7. Modelar, analizar y comunicar']
#
# pagina  rama
# P1      1 · Problemática y datos              6
#         2 · Entorno reproducible              5
#         3 · Herramientas científicas          4
#         4 · Estructura del entorno técnico    5
#         5 · Documentación científica          5
# P2      Ciclo colaborativo                    6
#         Flujo reproducible                    7
#    pagina                                rama  \
# 0      P1            1 · Problemática y datos
# 1      P1            1 · Problemática y datos
# 2      P1            1 · Problemática y datos
# 3      P1            1 · Problemática y datos
# 4      P1            1 · Problemática y datos
# 5      P1            1 · Problemática y datos
# 6      P1            2 · Entorno reproducible
# 7      P1            2 · Entorno reproducible
# 8      P1            2 · Entorno reproducible
# 9      P1            2 · Entorno reproducible
# 10     P1            2 · Entorno reproducible
# 11     P1        3 · Herramientas científicas
# 12     P1        3 · Herramientas científicas
# 13     P1        3 · Herramientas científicas
# 14     P1        3 · Herramientas científicas
# 15     P1  4 · Estructura del entorno técnico
# 16     P1  4 · Estructura del entorno técnico
# 17     P1  4 · Estructura del entorno técnico
# 18     P1  4 · Estructura del entorno técnico
# 19     P1  4 · Estructura del entorno técnico
# 20     P1        5 · Documentación científica
# 21     P1        5 · Documentación científica
# 22     P1        5 · Documentación científica
# 23     P1        5 · Documentación científica
# 24     P1        5 · Documentación científica
# 25     P2                  Flujo reproducible
# 26     P2                  Flujo reproducible
# 27     P2                  Flujo reproducible
# 28     P2                  Flujo reproducible
# 29     P2                  Flujo reproducible
# 30     P2                  Flujo reproducible
# 31     P2                  Flujo reproducible
# 32     P2                  Ciclo colaborativo
# 33     P2                  Ciclo colaborativo
# 34     P2                  Ciclo colaborativo
# 35     P2                  Ciclo colaborativo
# 36     P2                  Ciclo colaborativo
# 37     P2                  Ciclo colaborativo
#
#                                        nodo                 materializado_en  \
# 0                 Pregunta de investigación    F1 §1 · PROYECTO['preguntas']
# 1         Variable objetivo (duracion_dias)            F1 §5.3 · diccionario
# 2                     Factores explicativos   F1 §5.3 · metadatos_fase1.json
# 3        Fuente de datos (DataSF x8nh-xzn6)                  F1 §5.1 · FICHA
# 4                       Exploración inicial                   F1 §5.2 y §5.4
# 5                      Limitación declarada                     F1 §1 y §5.4
# 6                                Python 3.x        F1 §2 · verificar_entorno
# 7                     Entorno virtual .venv        F1 §2 · verificar_entorno
# 8                          requirements.txt  F1 §3.2 · escribir_requirements
# 9                              Semilla fija                    F1 §0 y F2 §1
# 10                          Rutas relativas           F1 §3 · localizar_raiz
# 11                         Jupyter Notebook                F1 y F2 completos
# 12                                Librerías             F1 §2 · DEPENDENCIAS
# 13                                      Git            F1 §6 · función git()
# 14                                   GitHub               Repositorio remoto
# 15                              Repositorio                Raíz del proyecto
# 16                                 Carpetas                            F1 §3
# 17                           Archivos clave               F1 §3.1, §3.2 y §9
# 18                      Commits proyectados               F1 §6 · convención
# 19              Criterios de versionamiento                   README y F1 §6
# 20                        Celdas narrativas                          F1 y F2
# 21                         Celdas de código                          F1 y F2
# 22                 Diccionario de variables                          F1 §5.3
# 23                       Metadatos por fase                    F1 §9 y F2 §9
# 24                          Informe técnico      Entregable de la Sumativa 1
# 25         1. Obtener y registrar la fuente                   F1 §5.1 y §5.4
# 26                 2. Configurar el entorno                     F1 §2 y §3.2
# 27               3. Estructurar y versionar                       F1 §3 y §6
# 28             4. Definir variables y roles                     F1 §5.3 y §9
# 29                 5. Limpiar y transformar                       F2 §3 a §7
# 30                               6. Validar                            F2 §8
# 31         7. Modelar, analizar y comunicar                      Fases 3 y 4
# 32                      Rama por integrante        Historial del repositorio
# 33                       Editar el notebook                          F1 y F2
# 34  Ejecutar de principio a fin sin errores                          F1 y F2
# 35                       Commit con prefijo        Historial del repositorio
# 36                      Push y pull request               Repositorio remoto
# 37             Integrar a la rama principal        Historial del repositorio
#
#                                             evidencia         estado
# 0                   Enunciado aprobado por el docente  Materializado
# 1   duracion_dias = permit_end_date - permit_start...  Materializado
# 2             Nueve variables explicativas declaradas  Materializado
# 3      Licencia PDDL 1.0; corte verificado 2026-09-09  Materializado
# 4               Perfil por columna, roles y faltantes  Materializado
# 5   docs/sesgo_seleccion.csv: mínimo creciente 2→9...  Materializado
# 6                 Intérprete y plataforma registrados  Materializado
# 7              Campo entorno_virtual en los metadatos  Materializado
# 8             Generado desde las versiones instaladas  Materializado
# 9   SEMILLA = 42 en ambos cuadernos y en los metad...  Materializado
# 10  Pruebas de la §4.1; ejecutado desde F1/notebooks/  Materializado
# 11      Numeración de ejecución continua, sin errores  Materializado
# 12  pandas, numpy, matplotlib, scikit-learn con ve...  Materializado
# 13                   Rama, commits y estado del árbol  Materializado
# 14                           URL citada en el informe  Materializado
# 15                            proyecto-grupo5-mcdi500  Materializado
# 16         data/raw, data/processed, docs, src, F1-F4  Materializado
# 17            README.md, requirements.txt, .gitignore  Materializado
# 18                    Prefijos feat, data, docs y fix  Materializado
# 19       Rama por integrante; datos crudos inmutables  Materializado
# 20        Cada decisión precedida de su justificación  Materializado
# 21                  Funciones con docstring y pruebas  Materializado
# 22       docs/diccionario_variables.csv, 23 variables  Materializado
# 23        metadatos_fase1.json y metadatos_fase2.json  Materializado
# 24        Ocho apartados, bibliografía APA 7 y anexos  Materializado
# 25               data/raw intacto; comprobación en F2  Materializado
# 26         requirements.txt generado desde el entorno  Materializado
# 27           Árbol creado y validado; consultas a git  Materializado
# 28  Diccionario y metadatos como contrato entre fases  Materializado
# 29  data/processed con los conjuntos limpio y proc...  Materializado
# 30  docs/validacion_fase2.csv, 12 de 12 comprobaci...  Materializado
# 31       Modelado, eficiencia algorítmica y hallazgos     Proyectado
# 32                  Ramas nominales antes de integrar  Materializado
# 33      Celda narrativa acompañada de celda de código  Materializado
# 34     Numeración de ejecución continua, cero errores  Materializado
# 35                             feat, data, docs y fix  Materializado
# 36                   Revisión previa a la integración  Materializado
# 37         git shortlog -sne con los tres integrantes  Materializado

# %% [markdown]
# > **Cómo se escribe esto en el informe.** La tabla no basta por sí sola. Cada fila debe
# > poder señalarse en un archivo, una celda o un *commit*: la columna de evidencia existe para
# > eso. Y conviene destacar que la correspondencia no es unidireccional: los nodos «Exploración
# > inicial» y «Limitación declarada» se incorporaron al mapa **después** de la retroalimentación
# > sobre la formativa, porque describen hallazgos que la planificación original no anticipaba.
# > Que el mapa haya evolucionado con el trabajo es evidencia de reflexión técnica, no un defecto
# > de planificación.

# %% [markdown]
# ## 9. Persistencia y trazabilidad
#
# El `README.md` se genera desde la configuración del proyecto, de modo que no pueda contradecir
# al cuaderno. Los archivos de `docs/` sostienen las tablas del informe técnico, y
# `metadatos_fase1.json` es además el **contrato** que la Fase 2 lee para saber qué variable es
# el objetivo, cuáles son explicativas y cuáles están prohibidas.
#
# Los **anexos del informe** se escriben aquí, en `docs/anexos/`, a partir de la salida capturada
# durante esta misma ejecución. De ese modo no hay que copiarlos a mano desde una captura de
# pantalla y no pueden quedar desactualizados respecto del cuaderno: esta fase aporta el Anexo A
# (verificación del entorno), el Anexo B (control de versiones) y la primera parte del Anexo G
# (pruebas del módulo).

# %%
def generar_readme(config, ficha, requisitos, ruta):
    """Escribe el README tecnico del repositorio a partir de la configuracion."""
    integrantes = "\n".join(f"- {n}" for n in config["integrantes"])
    dependencias = "\n".join(f"- {r}" for r in requisitos)

    contenido = f"""# {config['titulo']} — {config['grupo']}

{config['problematica']}

## Integrantes
{integrantes}

## Pregunta de investigación
{config['preguntas'][0]}

## Datos
- Fuente: {ficha['titulo']} ({ficha['autor']}, {ficha['plataforma']})
- Enlace: {ficha['url']}
- Licencia: {FICHA['licencia']}
- Corte: {FICHA['corte_declarado']} · descargado el {FICHA['descargado']}
- Actualización: {FICHA['frecuencia'].lower()}. El CSV en `data/raw/` ES el dato: volver a
  descargarlo produce un conjunto distinto y rompe la reproducibilidad.
- Conjunto de trabajo: {ficha['filas']} filas x {ficha['columnas']} columnas
- Ubicación esperada: `data/raw/`

## Limitación declarada
La fuente publica solo permisos vigentes, de modo que los de mayor duración quedan
sobrerrepresentados. Las conclusiones describen los permisos vigentes al corte, no la
población de permisos otorgados. El histórico sin ese filtro es `b6tj-gt35`.

## Estructura del repositorio
```
data/raw/        datos originales, sin modificar
data/processed/  datos tras limpieza y transformación (F2)
docs/            diccionario, fichas y metadatos
src/             módulos reutilizables del proyecto
F1/ F2/ F3/ F4/  cuadernos e informes de cada fase
```

## Requisitos y ejecución
    python -m venv .venv
    source .venv/bin/activate        # Windows: .venv\\Scripts\\activate
    python -m pip install -r requirements.txt

Ejecutar los cuadernos en orden: primero F1, después F2.

### Dependencias declaradas
{dependencias}

## Convención de commits
Prefijos usados: docs, data, feat, fix.

## Decisiones técnicas
- Los datos son comunes a todas las fases (`data/`); los cuadernos se separan por fase.
- La raíz del proyecto se detecta por marcador, no se asume igual al directorio de lanzamiento.
- Semilla aleatoria fijada en {SEMILLA} para asegurar reproducibilidad.
- El formato de las fechas se declara de forma explícita y nunca se deduce.
"""
    ruta.write_text(contenido, encoding="utf-8")
    return contenido


ARCHIVO_README = RAIZ / "README.md"
contenido = generar_readme(PROYECTO, FICHA_GRUPO, requisitos, ARCHIVO_README)
print(f"{ARCHIVO_README.relative_to(RAIZ).as_posix()} escrito "
      f"({len(contenido.splitlines())} líneas)\n")
print("\n".join(contenido.splitlines()[:14]), "\n...")
# Out:
# README.md escrito (60 líneas)
#
# # Factores asociados a la duración autorizada de los permisos de uso de vía pública en San Francisco — Grupo 5
#
# Los permisos de uso de vía pública regulan la ocupación temporal del espacio público por excavaciones, obras, instalaciones de telecomunicaciones y usos comerciales. La duración autorizada de cada permiso determina cuánto tiempo una calle queda afectada. El problema es de asociación: identificar qué factores se relacionan con esa duración, medida como el número de días entre la fecha de inicio y la de término del permiso.
#
# ## Integrantes
# - MARCO ÁLVAREZ ARAYA (@Marco30101994-Unab)
# - MARÍA FASSLER NEUMANN (@belenfassler)
# - RICARDO JARAMILLO PULGAR (@RJaramilloP)
#
# ## Pregunta de investigación
# ¿Qué proporción de la variación en la duración se asocia al tipo de permiso?
#
# ## Datos
# - Fuente: Active Street-Use Permits — conjunto de trabajo (San Francisco Public Works, DataSF)
# ...

# %%
#TODO: Ajustar cambios de enfoque de investigación según informe y feedback

# %%
# Artefactos de documentacion de la fase, en formato tabular para el informe.
diccionario.to_csv(DIR_DOCS / "diccionario_variables.csv", index=False, encoding="utf-8")
evaluacion.to_csv(DIR_DOCS / "evaluacion_criterios_dataset.csv", index=False, encoding="utf-8")
vinculacion.to_csv(DIR_DOCS / "vinculacion_mapa_conceptual.csv", index=False, encoding="utf-8")
if trabajo is not None:
    ausencia.to_csv(DIR_DOCS / "ausencia_informativa.csv", index=False, encoding="utf-8")
    tabla_sesgo.to_csv(DIR_DOCS / "sesgo_seleccion.csv", encoding="utf-8")
    comprobacion_fechas.to_csv(DIR_DOCS / "verificacion_fechas.csv", index=False, encoding="utf-8")

# Metadatos de la fase: lo que permite reconstruir en que condiciones se ejecuto,
# y el contrato que la Fase 2 lee.
METADATOS = {
    "proyecto": PROYECTO["titulo"],
    "grupo": PROYECTO["grupo"],
    "fase": "F1",
    "fecha_ejecucion": date.today().isoformat(),
    "semilla": SEMILLA,
    "python": sys.version.split()[0],
    "sistema": f"{platform.system()} {platform.release()}",
    "interprete": ENTORNO["interprete"],
    "entorno_virtual": ENTORNO["entorno_virtual"],
    "dependencias": ENTORNO["versiones"],
    "modo_rutas": MODO,
    "fuente": FICHA,
    "objetivo": OBJETIVO,
    "explicativas": EXPLICATIVAS,
    "variable_grupo": GRUPO_VAR,
    "prohibidas": PROHIBIDAS,
    "ausencia_informativa": ["Permit Purpose", "Inspector"],
    "descartes": utilidades.DESCARTES,
    "conjunto_trabajo": {"filas": FICHA_GRUPO["filas"], "columnas": FICHA_GRUPO["columnas"]},
    "criterios_incumplidos": incumplidos,
}
(DIR_DOCS / "metadatos_fase1.json").write_text(
    json.dumps(METADATOS, indent=2, ensure_ascii=False), encoding="utf-8")

# Anexos del informe: se generan desde esta misma ejecucion, no se copian a mano.
DIR_ANEXOS = DIR_DOCS / "anexos"
DIR_ANEXOS.mkdir(parents=True, exist_ok=True)
ANEXOS_F1 = {
    "anexo_a_entorno.txt": ANEXO_A,
    "anexo_b_control_versiones.txt": ANEXO_B,
    "anexo_g1_pruebas_fase1.txt": ANEXO_G1,
}
for nombre, texto in ANEXOS_F1.items():
    (DIR_ANEXOS / nombre).write_text(texto, encoding="utf-8")

for archivo in sorted(DIR_DOCS.rglob("*")):
    if archivo.is_file():
        print(f"  {archivo.relative_to(RAIZ).as_posix():46} {archivo.stat().st_size:7} bytes")
# Out:
#   docs/.DS_Store                                    6148 bytes
#   docs/anexos/INDICE_ANEXOS.md                      1539 bytes
#   docs/anexos/anexo_a_entorno.txt                    419 bytes
#   docs/anexos/anexo_b_control_versiones.txt         1048 bytes
#   docs/anexos/anexo_f1_forma_objetivo.png          66600 bytes
#   docs/anexos/anexo_f2_duracion_por_tipo.png       48388 bytes
#   docs/anexos/anexo_f3_patron_faltantes.png        69567 bytes
#   docs/anexos/anexo_f4_escaladores.png             48925 bytes
#   docs/anexos/anexo_g1_pruebas_fase1.txt             636 bytes
#   docs/anexos/anexo_g2_pruebas_fase2.txt             906 bytes
#   docs/ausencia_informativa.csv                      187 bytes
#   docs/ausencia_tratamiento.csv                      267 bytes
#   docs/columnas_descartadas.csv                      942 bytes
#   docs/comparacion_escalado.csv                      220 bytes
#   docs/comparacion_imputacion.csv                    169 bytes
#   docs/diccionario_variables.csv                    2049 bytes
#   docs/evaluacion_criterios_dataset.csv              726 bytes
#   docs/mapa_conceptual/mapa_p1_jerarquia.mermaid    5740 bytes
#   docs/mapa_conceptual/mapa_p1_jerarquia.png      274656 bytes
#   docs/mapa_conceptual/mapa_p2_flujo.mermaid        4064 bytes
#   docs/mapa_conceptual/mapa_p2_flujo.png          170257 bytes
#   docs/metadatos_fase1.json                         3177 bytes
#   docs/metadatos_fase2.json                         1579 bytes
#   docs/metadatos_fase2_plano.csv                    1369 bytes
#   docs/sesgo_seleccion.csv                           152 bytes
#   docs/validacion_fase2.csv                          820 bytes
#   docs/verificacion_fechas.csv                       214 bytes
#   docs/vinculacion_mapa_conceptual.csv              4848 bytes

# %%
# Resumen de cierre: que existia al empezar y que queda al terminar la fase.
resumen = pd.DataFrame([
    {"artefacto": "Modo de resolución de rutas", "estado": MODO},
    {"artefacto": "Carpetas del proyecto",
     "estado": len([p for p in RAIZ.rglob("*") if p.is_dir() and ".git" not in p.parts
                    and "__pycache__" not in p.parts])},
    {"artefacto": "Archivos en docs/",
     "estado": len([p for p in DIR_DOCS.iterdir() if p.is_file()])},
    {"artefacto": "Dependencias declaradas", "estado": len(requisitos)},
    {"artefacto": "Variables en el diccionario", "estado": len(diccionario)},
    {"artefacto": "Variables explicativas", "estado": len(EXPLICATIVAS)},
    {"artefacto": "Variables prohibidas", "estado": len(PROHIBIDAS)},
    {"artefacto": "Nodos del mapa vinculados", "estado": len(vinculacion)},
    {"artefacto": "Anexos generados en esta fase", "estado": len(ANEXOS_F1)},
    {"artefacto": "Criterios de dataset incumplidos", "estado": len(incumplidos)},
    {"artefacto": "Conjunto cargado y verificado", "estado": "sí" if trabajo is not None else "NO"},
    {"artefacto": "Repositorio git", "estado": "sí" if es_repo else "pendiente"},
])
resumen
# Out:
#                            artefacto        estado
# 0        Modo de resolución de rutas  estructurado
# 1              Carpetas del proyecto          1701
# 2                  Archivos en docs/            15
# 3            Dependencias declaradas             7
# 4        Variables en el diccionario            23
# 5             Variables explicativas            11
# 6               Variables prohibidas             3
# 7          Nodos del mapa vinculados            38
# 8      Anexos generados en esta fase             3
# 9   Criterios de dataset incumplidos             0
# 10     Conjunto cargado y verificado            sí
# 11                   Repositorio git            sí

# %% [markdown]
# ## Conclusiones y trazabilidad
#
# La fase deja operativo un entorno verificado, una estructura de repositorio con sus artefactos
# de reproducibilidad (`.gitignore`, `requirements.txt`, `README.md`), un módulo propio
# importable y probado, y la documentación del conjunto de datos con su evaluación contra los
# criterios del curso. Cada paso se implementó como una función documentada y verificada:
# `presentar_proyecto`, `verificar_entorno`, `localizar_raiz`, `escribir_requirements`,
# `evaluar_criterios`, `git`, `validar_fase1` y `generar_readme`.
#
# **Trazabilidad con el repositorio (F1):** este cuaderno se ubica en `F1/notebooks/`; el
# `README` documenta dependencias e instrucciones de ejecución; los archivos de `docs/`
# sostienen las tablas del informe técnico, y el historial de *commits* refleja el avance
# descrito en él.
#
# **Entrada a la Fase 2.** `docs/diccionario_variables.csv` y `docs/metadatos_fase1.json` son el
# contrato de esta fase. El cuaderno de la Fase 2 los lee y se detiene si no los encuentra: qué
# variable es el objetivo y cuáles se excluyen por fuga se decidió aquí, con evidencia, y no se
# vuelve a decidir.

# %% [markdown]
# ---
#
# ## 10. Reflexión técnica
#
# ### Hallazgos
#
# - **El archivo tal como se descarga no sirve como conjunto de análisis.** La evaluación de la
#   sección 5.2 lo muestra sin ambigüedad: no hay ninguna variable numérica discreta y tres
#   columnas superan el 60 % de faltantes. Descubrirlo antes de comprometerse con él es
#   precisamente para lo que sirve evaluar el conjunto. El plan de saneamiento resuelve ambos
#   incumplimientos y el conjunto de trabajo supera los diez criterios.
#
# - **El rol analítico no basta: hace falta declarar el uso.** `permit_start_date` y
#   `permit_end_date` son fechas impecables y aun así no pueden explicar nada, porque la duración
#   es su resta. Esa distinción no cabe en la columna de rol y obligó a añadir una segunda.
#
# - **La conversión automática de tipos es más peligrosa cuando no avisa.** En las dos columnas
#   cuyo primer valor no era ambiguo, la librería dedujo el formato correcto, ignoró la opción
#   solicitada y lo advirtió. En la única cuyo primer valor sí era ambiguo, obedeció en silencio
#   y alteró 2.257 registros. La columna en la que no hubo advertencia es la que quedó corrompida.
#
# - **La ausencia de un dato puede ser el dato.** Los permisos sin descripción de propósito duran
#   casi nueve veces más que los que la tienen. Imputar ese hueco habría borrado la señal.
#
# - **La fuente tiene un sesgo que se puede medir, no solo declarar.** La duración mínima
#   observada crece con la antigüedad del permiso —de 2 a 98, a 437, a 997 días—, que es
#   exactamente lo que predice el filtro de vigencia del portal.
#
# ### Dificultades y cómo se resolvieron
#
# - **Rutas.** Fijar la raíz como el directorio de lanzamiento habría creado dos árboles de
#   archivos paralelos, uno por cada cuaderno. Se resolvió detectando la raíz por marcador de
#   repositorio, con pruebas que cubren el caso normal, el límite y la excepción.
#
# - **Dependencia del archivo de datos.** El cuaderno no falla si el conjunto todavía no está
#   descargado: informa qué falta y continúa.
#
# - **Fuente que cambia a diario.** El corte no se da por supuesto: se verifica contra el sello
#   `data_as_of` del propio archivo y se avisa si no coincide con lo declarado en la ficha.
#
# ### Decisiones que quedan abiertas
#
# - Si en algún momento conviene contrastar contra el conjunto histórico `b6tj-gt35`, que no
#   tiene el sesgo de vigencia pero sí 1,2 millones de registros.

# %% [markdown]
# ---
#
# ## 11. Verificación antes de entregar
#
# **Cuaderno**
#
# - Corre completo tras *Kernel → Restart Kernel and Run All Cells*, sin errores.
# - La numeración de ejecución es continua.
# - Cada bloque de código está precedido por una celda narrativa que explica su lógica.
# - Todas las rutas son relativas y la semilla está declarada.
#
# **Contenido técnico**
#
# - La problemática, los objetivos, el alcance y las limitaciones están declarados.
# - El entorno se verifica con evidencia (intérprete, entorno virtual, versiones).
# - La procedencia del conjunto está documentada, con enlace, licencia y cita en APA 7.
# - El diccionario declara el rol analítico **y el uso** de cada variable.
# - El conjunto candidato fue evaluado contra los criterios del curso, antes y después del
#   saneamiento.
# - Hay pruebas de casos normales, límite y excepciones.
#
# **Archivos**
#
# - `.gitignore` y `requirements.txt` en la raíz, ambos con contenido.
# - `README.md` técnico, generado desde la configuración del proyecto.
# - `docs/` con diccionario, evaluación del conjunto, vinculación, verificaciones y metadatos.
# - `src/utilidades.py` importable.
#
# **Pendiente del grupo**
#
# - Completar los nombres de los tres integrantes en `PROYECTO`.
# - Inicializar el repositorio y verificar que `git shortlog -sne` muestra a los tres.
# - Comprobar que el correo de Git coincide con el de la cuenta de GitHub.
#
# ---
#
# *Cuaderno de la Fase 1 · Grupo 5 · MCDI500 · Magíster en Ciencia de Datos e Inteligencia
# Artificial · Universidad Andrés Bello*
